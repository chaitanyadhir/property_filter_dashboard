# %% [markdown]
# # making data power bi ready

# %%
import numpy as np
import re
import pandas as pd
from sklearn.impute import KNNImputer

# %% [markdown]
# after importing all the neccessary libraries, now we will load all the csv files

# %%
df_kolkata=pd.read_csv("kolkata.csv")
df_gurgaon=pd.read_csv("gurgaon_10k.csv", low_memory=False)
df_mumbai=pd.read_csv("mumbai.csv")
df_hyderabad=pd.read_csv("hyderabad.csv")

# %%
df_kolkata.shape
# Out:
# (8797, 35)

# %%
df_gurgaon.shape
# Out:
# (10704, 67)

# %%
df_mumbai.shape
# Out:
# (9514, 55)

# %%
df_hyderabad.shape
# Out:
# (9487, 55)

# %% [markdown]
# lets make a single csv file with all the common columns

# %%
common_columns = set(df_kolkata.columns) & set(df_gurgaon.columns) & set(df_mumbai.columns) & set(df_hyderabad.columns)

# %%
common_columns = list(common_columns)
print(common_columns)
# Out:
# ['PRICE_PER_UNIT_AREA', 'PROPERTY_TYPE', 'DESCRIPTION', 'TRANSACT_TYPE', 'PROP_HEADING', 'AMENITIES', 'OWNTYPE', 'PRICE_SQFT', 'BALCONY_NUM', 'AGE', 'location', 'CITY', 'BEDROOM_NUM', 'TOTAL_FLOOR', 'FURNISH', 'SOCIETY_NAME', 'PROP_ID', 'PREFERENCE', 'FORMATTED_LANDMARK_DETAILS', 'SECONDARY_TAGS', 'MAP_DETAILS', 'FEATURES', 'BUILDING_NAME', 'TOTAL_LANDMARK_COUNT', 'FLOOR_NUM', 'PROP_NAME', 'FACING', 'PRICE', 'AREA']

# %%
df_kolkata_common = df_kolkata[common_columns]
df_gurgaon_common = df_gurgaon[common_columns]
df_mumbai_common = df_mumbai[common_columns]
df_hyderabad_common = df_hyderabad[common_columns]

# %%
final_df = pd.concat([df_kolkata_common, df_gurgaon_common, df_mumbai_common, df_hyderabad_common], ignore_index=True)

# %%
final_df.to_csv('final.csv', index=False)

# %%
df=pd.read_csv("final.csv")

# %%
df.head()
# Out:
#    PRICE_PER_UNIT_AREA          PROPERTY_TYPE  \
# 0               3662.0  Residential Apartment
# 1              10500.0  Residential Apartment
# 2               8900.0  Residential Apartment
# 3                208.0       Residential Land
# 4               5215.0  Residential Apartment
#
#                                          DESCRIPTION  TRANSACT_TYPE  \
# 0  Book your 2 BHK flat in Srijan Star Swapno Pur...            2.0
# 1  Make Natural Quest your next home. This projec...            2.0
# 2  Book your 3 BHK apartment in Garia, Kolkata So...            2.0
# 3  Dev bhumi in joka, kolkata south by ocean land...            2.0
# 4  Let your dream of owning a flat come true with...            2.0
#
#                       PROP_HEADING AMENITIES  OWNTYPE  PRICE_SQFT  \
# 0             2 BHK Flat in Amtala       NaN        1      3662.0
# 1          3 BHK Flat in EM Bypass       NaN        1     10500.0
# 2              3 BHK Flat in Garia       NaN        1      8900.0
# 3  Residential land / Plot in Joka       NaN        1       208.0
# 4               3 BHK Flat in Joka       NaN        1      5215.0
#
#    BALCONY_NUM  AGE  ...                                     SECONDARY_TAGS  \
# 0          NaN    5  ...  ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA | ...
# 1          NaN    5  ...  ['UNDER CONSTRUCTION', 'NEW LAUNCH', 'NEW BOOK...
# 2          NaN    5  ...  ['UNDER CONSTRUCTION', 'NEW LAUNCH', 'NEW BOOK...
# 3          NaN    0  ...                   ['READY TO MOVE', 'NEW BOOKING']
# 4          NaN    5  ...              ['UNDER CONSTRUCTION', 'NEW BOOKING']
#
#                                          MAP_DETAILS  FEATURES  \
# 0  {'LATITUDE': '22.364447', 'LONGITUDE': '88.274...         N
# 1  {'LATITUDE': '22.518795', 'LONGITUDE': '88.388...         N
# 2  {'LATITUDE': '22.5137646', 'LONGITUDE': '88.36...         N
# 3  {'LATITUDE': '22.45383', 'LONGITUDE': '88.2495...         N
# 4  {'LATITUDE': '22.44213', 'LONGITUDE': '88.29551'}         N
#
#               BUILDING_NAME  TOTAL_LANDMARK_COUNT FLOOR_NUM  \
# 0  Srijan Star Swapno Puron                   2.0         1
# 1             Natural Quest                   9.0         1
# 2   Ganguly 4Sight Eminence                   6.0         1
# 3                 Dev Bhumi                  13.0       NaN
# 4                 DTC Sojon                  11.0         1
#
#                   PROP_NAME FACING            PRICE               AREA
# 0  Srijan Star Swapno Puron      0   19.1 L Onwards    518-623  sq.ft.
# 1             Natural Quest      0  1.17  - 1.18 Cr  1110-1121  sq.ft.
# 2   Ganguly 4Sight Eminence      0  1.22  - 1.35 Cr  1376-1516  sq.ft.
# 3                 Dev Bhumi      0    1.5  - 5.99 L   720-2880  sq.ft.
# 4                 DTC Sojon      0       60  - 75 L  1130-1460  sq.ft.
#
# [5 rows x 29 columns]

# %% [markdown]
# now we will do sanity check of the data

# %%
df.shape
# Out:
# (38502, 29)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 38502 entries, 0 to 38501
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38502 non-null  float64
#  1   PROPERTY_TYPE               38502 non-null  object
#  2   DESCRIPTION                 38502 non-null  object
#  3   TRANSACT_TYPE               31988 non-null  float64
#  4   PROP_HEADING                38502 non-null  object
#  5   AMENITIES                   30485 non-null  object
#  6   OWNTYPE                     38502 non-null  int64
#  7   PRICE_SQFT                  38502 non-null  float64
#  8   BALCONY_NUM                 28505 non-null  float64
#  9   AGE                         38502 non-null  int64
#  10  location                    38502 non-null  object
#  11  CITY                        38502 non-null  object
#  12  BEDROOM_NUM                 34948 non-null  float64
#  13  TOTAL_FLOOR                 37850 non-null  float64
#  14  FURNISH                     38502 non-null  int64
#  15  SOCIETY_NAME                33484 non-null  object
#  16  PROP_ID                     38502 non-null  object
#  17  PREFERENCE                  38502 non-null  object
#  18  FORMATTED_LANDMARK_DETAILS  36361 non-null  object
#  19  SECONDARY_TAGS              38502 non-null  object
#  20  MAP_DETAILS                 38502 non-null  object
#  21  FEATURES                    38502 non-null  object
#  22  BUILDING_NAME               33471 non-null  object
#  23  TOTAL_LANDMARK_COUNT        36361 non-null  float64
#  24  FLOOR_NUM                   31981 non-null  object
#  25  PROP_NAME                   33484 non-null  object
#  26  FACING                      38502 non-null  int64
#  27  PRICE                       38502 non-null  object
#  28  AREA                        38502 non-null  object
# dtypes: float64(7), int64(4), object(18)
# memory usage: 8.5+ MB

# %%
df.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA              0
# PROPERTY_TYPE                    0
# DESCRIPTION                      0
# TRANSACT_TYPE                 6514
# PROP_HEADING                     0
# AMENITIES                     8017
# OWNTYPE                          0
# PRICE_SQFT                       0
# BALCONY_NUM                   9997
# AGE                              0
# location                         0
# CITY                             0
# BEDROOM_NUM                   3554
# TOTAL_FLOOR                    652
# FURNISH                          0
# SOCIETY_NAME                  5018
# PROP_ID                          0
# PREFERENCE                       0
# FORMATTED_LANDMARK_DETAILS    2141
# SECONDARY_TAGS                   0
# MAP_DETAILS                      0
# FEATURES                         0
# BUILDING_NAME                 5031
# TOTAL_LANDMARK_COUNT          2141
# FLOOR_NUM                     6521
# PROP_NAME                     5018
# FACING                           0
# PRICE                            0
# AREA                             0
# dtype: int64

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# PRICE_PER_UNIT_AREA            0.000000
# PROPERTY_TYPE                  0.000000
# DESCRIPTION                    0.000000
# TRANSACT_TYPE                 16.918602
# PROP_HEADING                   0.000000
# AMENITIES                     20.822295
# OWNTYPE                        0.000000
# PRICE_SQFT                     0.000000
# BALCONY_NUM                   25.964885
# AGE                            0.000000
# location                       0.000000
# CITY                           0.000000
# BEDROOM_NUM                    9.230689
# TOTAL_FLOOR                    1.693419
# FURNISH                        0.000000
# SOCIETY_NAME                  13.033089
# PROP_ID                        0.000000
# PREFERENCE                     0.000000
# FORMATTED_LANDMARK_DETAILS     5.560750
# SECONDARY_TAGS                 0.000000
# MAP_DETAILS                    0.000000
# FEATURES                       0.000000
# BUILDING_NAME                 13.066854
# TOTAL_LANDMARK_COUNT           5.560750
# FLOOR_NUM                     16.936783
# PROP_NAME                     13.033089
# FACING                         0.000000
# PRICE                          0.000000
# AREA                           0.000000
# dtype: float64

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
for i in df.select_dtypes(include="object").columns:
    print(df[i].value_counts())
    print("***"*10)
# Out:
# Residential Apartment        28548
# Residential Land              3529
# Independent/Builder Floor     3187
# Independent House/Villa       2951
# Studio Apartment               163
# Serviced Apartments             80
# Farm House                      40
# Other                            2
# Name: PROPERTY_TYPE, dtype: int64
# ******************************
# Its on main road. Sarrounding villas & apartments projects available.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            92
# All modes of public conveyance such as tmt/nmtc/ best buses, pvt. Buses, auto rickshaw, taxi etc are available almost 24 x 7 hrs. All the day to day requirements such as restaurants, grocery shops, malls, banks, atm's, schools & colleges are available in close vicinity.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   56
# Very nicely built up ultra luxury builder floor with excellent interiors done with natural sunlight, all wardrobes are of ceiling hight, hettich modular kitchen, luxury washrooms with jaquar sanitary fittings wooden flooring in master bedroom, video door phone with electronic lock on the main gate and staircase gate, full length balcony with upvc windows, reserved car parking for visitors as well. This property offers a chance to witness to calm and reposed lifestyle amongst lush greenery . Walkin distance to huda market, swiss cottage school and manipal hospital.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       51
# Gated community. Its in prime locality. Sarrounding villa & appartments project avail.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           46
# Rera and hmda approved open plots for sale, north and east facing plots are available, spot registration.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        46
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  ..
# Emaar mgf palm terraces select elevationall photos & videos18\nVideos2\nEmaar mgf palm terraces select entranceoutdoors3\nHome\n\nProjects in gurgaon\n\nSector 66 gurgaon\n\nEmaar mgf palm terraces select\nEmaar mgf palm terraces select gurgaonemaar mgf palm terraces select \nSector 66, gurgaon\nRerano brokerage3d floor plans available+20 top facilities\nRequest callback\n4.6\n\nOverall rating\nBased on 3 reviews\nConstruction status\nReady to move\nSince aug, 2021\n 1.98 - 4.4 cr\n+ govt. Charges\nDownload brochure\nPrice range\n3, 4, 5 bhk apartment\n3 bhk\nApartment\nSuper built-Up area\n1650 sq.Ft.\n(153.29 sq.M.)\n 1.98 - 2.06 cr\n+ govt. Charges\n4 bhk\nApartment\nSuper built-Up area\n2410 sq.Ft.\n(223.9 sq.M.)\n 2.89 - 3.01 cr\n+ govt. Charges\n5 bhk\nApartment\nSuper built-Up area\n3670 sq.Ft.\n(340.95 sq.M.)\n 4.4 cr\n+ govt. Charges\nFloor plans & pricing\n3 bhk apartment4 bhk apar...5 bhk apar...\n1 floor plan available\n 1.98 - 2.06 cr\n1650 sq.Ft.\n(153.29 sq.M.)\nSuper built-Up area | 3 bhk\n\nReady to move\nUnits available with completion in aug 21\nRequest callback\nSellers you may contact for more details\nView all sellers\n3 bhk apartment4 bhk apartment5 bhk apartment\nDiscover home\nDiscover home\nRera registered dealer\nView contact\nGrrow property management pvt. Ltd.\nRera registered dealer\nView contact\nTop facilities\nView all (25)\nEmaar mgf palm terraces select gurgaon presents an exclusive opportunity to own ...\n\nBowling_alley\nBowling alley\nSwimming_pool\nSwimming pool\nBar_chill_out_lounge\nBar/chill-Out lounge\nChanging_area\nChanging area\nAerobics_centre\nAerobics centre\nJacuzzi\nJacuzzi\nBilliards\nBilliards\nLawn_tennis_court\nLawn tennis court\nParty_lawn\nParty lawn\nView facility photos\nLocation advantages\nView all (8)\nSector 66 is one of the prime locations to buy a home in gurgaon. There are 13 r...\n\nGolf course ext rd\n900 meter\nDps international edge\n1.5 km\nOmaxe gurgaon mall\n2.6 km\nPark hospital\n2.8 km\nSector 55/56 metro station\n7.1 km\nBadshahpur sohna rd hwy\n7.1 km\nSushant university\n7.8 km\nIndira gandhi intl airport\n22.8 km\nMore about emaar mgf palm terraces select\nEmaar mgf palm terraces select in sector 66, gurgaon is a ready-To-Move housing society. It offers apartments and independent floors in varied budget range. These units are a perfect combination of comfort and style, specifically designed to suit you...More     1
# 2bhk main 30mtr road 202sq.Yd park facing plot for sale in sector 30 gurgaon prime location suitable for doctor ca and other commercial use and residential use more details cal us.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              1
# Hi, we have an independent floor available for sale in adani samsara vilasa, sector 63, gurugram, haryana                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         1
# Located in phase v of dlf city, the apartments offer the twin benefits of being situated in a green belt coupled with conveniences for shopping, thereby providing for a healthy and comfortable lifestyle . Dlf princeton estate is endowed with all the facilities and amenities sought for a standard living. Situated in phase-V, gurgaon, a location well surrounded by schools, hospitals, shopping centers and many more, dlf princeton estate gurgaon makes you live a life in style. Garden, play area, maintenance staff, security personnel, electricity backup, etc. Are here to enamor you with. Every apartment is befitted with power back up and comprehensive safety and security measures.                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      1
# Grama panchayithi approval\nProject located at: Puppalaguda colony manikonda (Behind sri lakshmi narasimha swamy temple)\nProject details:\nFloors: Stilt + 5 floors\nTotal flats: \nFacings: East & north \nVariants and sizes\n2 bhk- Flats\n1200 sft - (East)\n1220 sft - (North)\n Pricing details: -\nBasic cost: 5250 /- Per sft +\nAminitie : 400000\nProject highlights:\n In close proximity to main road\n Just 3.5 kms from kphb metro station station.\n Seperate car parkings for each flat \n Municipal water supply \n Lift facility \n Cctv surveillance in all common areas \n Borewell provision \n Drinking water connection \n 100% vastu complaint \n No common walls\n Excellent ventilation from all sides\n Generator power backup\n Strategic location \n 24 hrs water supply\nEducational institutions\nPavitra international school :1 min\nScolars international school: 4 min\n Hospitals\nAvasa hospital: 4 mins\nBalaji hospital: 6 mins\nAvmi hospital: 4 mins\nKims hospitals gachibowli: 10 mins\n Transportation \n Gachibowli -5 mins\n Hitechcity - 10 mins\n Outerring road (Orr) - 25mins\n Hitech city railway station - 10mins                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# Name: DESCRIPTION, Length: 35015, dtype: int64
# ******************************
# 3 BHK Flat in New Town                          655
# 2 BHK Flat in New Town                          319
# 3 BHK Flat in Kondapur                          316
# 2 BHK Flat in Rajarhat                          296
# 3 BHK Flat in Rajarhat                          278
#                                                ...
# 2 BHK Flat in Palaspa                             1
# 1 Bedroom House in Airoli                         1
# 1 BHK Flat in BARC JARO GOVANDI DR CG ROAD        1
# 2 BHK Flat in Sector 23 Nerul                     1
# Studio Apartments / 1 RK Flats in Panjagutta      1
# Name: PROP_HEADING, Length: 5967, dtype: int64
# ******************************
# 5,23,24,26                                                                                            1818
# 5,17,20,21,23,24,6,19,101,102                                                                          831
# 5,17,20,21,23,24,6,19,101,102,103                                                                      769
# 10,32,17,5,8,20,21,44,23,45,24,46,47,28,29,30,39,19,1,6,9,40,41,42,43,25,26,31,33,12,3,101,102,103     427
# 5,17,20,21,23,24,6,19                                                                                  411
#                                                                                                       ...
# 17,8,21,32,23,47,19,1,9,40,41,30,42,12,25,26,3,103                                                       1
# 17,21,23,47,19,1,9,40,30,41,42,12,25,26,3,103                                                            1
# 17,8,21,32,23,24,47,19,1,9,40,30,41,42,12,25,26,3,103                                                    1
# 21,23,1,24,6,19,41,42,43,12,3,26,103                                                                     1
# 5,21,44,23,39,19,9,40                                                                                    1
# Name: AMENITIES, Length: 14732, dtype: int64
# ******************************
# {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'LOCALITY_ID': '1503', 'LOCALITY_NAME': 'New Town', 'ADDRESS': None}                                                                                                                                          1077
# {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'LOCALITY_ID': '1495', 'LOCALITY_NAME': 'Rajarhat', 'ADDRESS': None}                                                                                                                                           524
# {'CITY': '27', 'CITY_NAME': 'Kolkata South', 'LOCALITY_ID': '844', 'LOCALITY_NAME': 'Joka', 'ADDRESS': None}                                                                                                                                               356
# {'CITY': '27', 'CITY_NAME': 'Kolkata South', 'LOCALITY_ID': '598', 'LOCALITY_NAME': 'Tollygunge', 'ADDRESS': None}                                                                                                                                         265
# {'CITY': '27', 'CITY_NAME': 'Kolkata South', 'LOCALITY_ID': '603', 'LOCALITY_NAME': 'EM Bypass', 'ADDRESS': None}                                                                                                                                          213
#                                                                                                                                                                                                                                                           ...
# {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDING_ID': '1102794', 'BUILDING_NAME': 'Signature Global City 93', 'SOCIETY_NAME': 'Signature Global City 93', 'LOCALITY_ID': '2483', 'LOCALITY_NAME': 'Sector 93 Gurgaon', 'ADDRESS': '402'}                      1
# {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDING_ID': '4638', 'BUILDING_NAME': 'Tata Primanti', 'SOCIETY_NAME': 'Tata Primanti', 'LOCALITY_ID': '8504', 'LOCALITY_NAME': 'Sector 72 Gurgaon', 'ADDRESS': '4bhk'}                                              1
# {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDING_ID': '904006', 'BUILDING_NAME': 'Krisumi Waterfall Residences', 'SOCIETY_NAME': 'Krisumi Waterfall Residences', 'LOCALITY_ID': '28421', 'LOCALITY_NAME': 'Sector 36A Gurgaon', 'ADDRESS': 'Penthouse'}       1
# {'CITY': '8', 'CITY_NAME': 'Gurgaon', 'BUILDING_ID': '0', 'BUILDING_NAME': 'Whiteland The Aspen', 'SOCIETY_NAME': 'Whiteland The Aspen', 'LOCALITY_ID': '7718', 'LOCALITY_NAME': 'Sector 76 Gurgaon', 'ADDRESS': 'T-1'}                                      1
# {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUILDING_ID': '0', 'BUILDING_NAME': 'Pavan Heights', 'SOCIETY_NAME': 'Pavan Heights', 'LOCALITY_ID': '8045', 'LOCALITY_NAME': 'Manikonda', 'ADDRESS': '302'}                                                      1
# Name: location, Length: 16614, dtype: int64
# ******************************
# Gurgaon                   10704
# Hyderabad                  8762
# Kolkata South              3802
# Kolkata East               2880
# Navi Mumbai                2194
# Kolkata North              1797
# Central Mumbai suburbs     1753
# Mumbai Andheri-Dahisar     1553
# Thane                      1483
# South Mumbai                810
# Secunderabad                724
# Mumbai Beyond Thane         509
# Mumbai Harbour              418
# Mira Road And Beyond        405
# Mumbai South West           388
# Kolkata West                243
# Kolkata Central              75
# Name: CITY, dtype: int64
# ******************************
# On Request                                 329
# on request                                 307
# Prestige High Fields                       238
# Emaar Digihomes                            134
# Aparna Sarovar Zenith                      103
#                                           ...
# jari mari cottage room num 7..1st floor      1
# Hi Tech Luxus Tower                          1
# Karnani CHS                                  1
# Orient Platinum                              1
# Pavan Heights                                1
# Name: SOCIETY_NAME, Length: 9855, dtype: int64
# ******************************
# N70806490    2
# C70363976    2
# P70247048    2
# E69809784    2
# I70038378    2
#             ..
# Q71148220    1
# O69749206    1
# E68637772    1
# P69948042    1
# Q70748632    1
# Name: PROP_ID, Length: 38487, dtype: int64
# ******************************
# S    32008
# R     4613
# P     1879
# Name: PREFERENCE, dtype: int64
# ******************************
# [{'category': 'MetroStation', 'text': '1 Metro Station', 'className': 'mstn', 'icon': 'https://static.99acres.com/universalapp/img/mstn.png'}, {'category': 'Shopping', 'text': '1 Shopping', 'className': 'shpng', 'icon': 'https://static.99acres.com/universalapp/img/shpng.png'}, {'category': 'Connectivity', 'text': '1 Connectivity', 'className': 'hw', 'icon': 'https://static.99acres.com/universalapp/img/hw.png'}, {'category': 'Education', 'text': '2 Educations', 'className': 'schl', 'icon': 'https://static.99acres.com/universalapp/img/schl.png'}, {'category': 'Hospital', 'text': '1 Hospital', 'className': 'hsptl', 'icon': 'https://static.99acres.com/universalapp/img/hsptl.png'}, {'category': 'Airport', 'text': '1 Airport', 'className': 'aprt', 'icon': 'https://static.99acres.com/universalapp/img/aprt.png'}, {'category': 'RailwayStation', 'text': '1 Railway Station', 'className': 'rail', 'icon': 'https://static.99acres.com/universalapp/img/rail.png'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 519
# [{'text': '1 Metro Station'}, {'text': '1 Shopping'}, {'text': '1 Connectivity'}, {'text': '2 Educations'}, {'text': '1 Hospital'}, {'text': '1 Airport'}, {'text': '1 Railway Station'}, {'text': '1 Office Complex'}, {'text': '1 Hotels'}, {'text': '1 Amusement Park'}, {'text': '1 Golf Course'}, {'text': '1 Stadium'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      478
# [{'category': 'MetroStation', 'text': '1 Metro Station', 'className': 'mstn', 'icon': 'https://static.99acres.com/universalapp/img/mstn.png'}, {'category': 'Shopping', 'text': '1 Shopping', 'className': 'shpng', 'icon': 'https://static.99acres.com/universalapp/img/shpng.png'}, {'category': 'Connectivity', 'text': '1 Connectivity', 'className': 'hw', 'icon': 'https://static.99acres.com/universalapp/img/hw.png'}, {'category': 'Education', 'text': '2 Educations', 'className': 'schl', 'icon': 'https://static.99acres.com/universalapp/img/schl.png'}, {'category': 'Hospital', 'text': '1 Hospital', 'className': 'hsptl', 'icon': 'https://static.99acres.com/universalapp/img/hsptl.png'}, {'category': 'Airport', 'text': '1 Airport', 'className': 'aprt', 'icon': 'https://static.99acres.com/universalapp/img/aprt.png'}, {'category': 'RailwayStation', 'text': '1 Railway Station', 'className': 'rail', 'icon': 'https://static.99acres.com/universalapp/img/rail.png'}, {'category': 'OfficeComplex', 'text': '1 Office Complex', 'className': 'ofce', 'icon': 'https://static.99acres.com/universalapp/img/ofce.png'}, {'category': 'Hotel', 'text': '1 Hotels', 'className': 'htl', 'icon': 'https://static.99acres.com/universalapp/img/htl.png'}, {'category': 'AmusementPark', 'text': '1 Amusement Park', 'className': 'amprk', 'icon': 'https://static.99acres.com/universalapp/img/amprk.png'}, {'category': 'GolfCourse', 'text': '1 Golf Course', 'className': 'golf', 'icon': 'https://static.99acres.com/universalapp/img/golf.png'}, {'category': 'Stadium', 'text': '1 Stadium', 'className': 'stdm', 'icon': 'https://static.99acres.com/universalapp/img/stdm.png'}]    332
# [{'category': 'ReligiousPlace', 'text': '2 Religious Places', 'className': 'rlgs', 'icon': 'https://static.99acres.com/universalapp/img/rlgs.png'}, {'category': 'ATM', 'text': '3 ATMs', 'className': 'atm', 'icon': 'https://static.99acres.com/universalapp/img/atm_blue.png'}, {'category': 'Hospital', 'text': '5 Hospitals', 'className': 'hsptl', 'icon': 'https://static.99acres.com/universalapp/img/hsptl.png'}, {'category': 'OfficeComplex', 'text': '4 Office Complexes', 'className': 'ofce', 'icon': 'https://static.99acres.com/universalapp/img/ofce.png'}, {'category': 'Parking', 'text': '1 Parking', 'className': 'prkng', 'icon': 'https://static.99acres.com/universalapp/img/prkng.png'}, {'category': 'BusDepot', 'text': '2 Bus Depots', 'className': 'busdpt', 'icon': 'https://static.99acres.com/universalapp/img/busdpt.png'}, {'category': 'Miscellaneous', 'text': '1 Miscellaneous', 'className': 'oldhme', 'icon': 'https://static.99acres.com/universalapp/img/oldhme.png'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    261
# [{'text': '1 Hospital'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           250
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   ...
# [{'text': '1 Railway Station'}, {'text': '2 Shoppings'}, {'text': '1 Connectivity'}, {'text': '3 Educations'}, {'text': '1 ATM'}, {'text': '3 Hospitals'}, {'text': '1 Banks'}, {'text': '2 Pharmacys'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             1
# [{'text': '2 Shoppings'}, {'text': '5 ATMs'}, {'text': '2 Hospitals'}, {'text': '3 Bankss'}, {'text': '3 Miscellaneouss'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                           1
# [{'text': '1 Metro Station'}, {'text': '4 Religious Places'}, {'text': '31 Hospitals'}, {'text': '1 Miscellaneous'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 1
# [{'text': '2 Religious Places'}, {'text': '6 ATMs'}, {'text': '28 Hospitals'}, {'text': '1 Attraction'}, {'text': '4 Pharmacys'}, {'text': '1 Swimming Pool'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       1
# [{'text': '2 Metro Stations'}, {'text': '1 Religious Place'}, {'text': '17 Hospitals'}, {'text': '2 Attractions'}, {'text': '3 Miscellaneouss'}]                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     1
# Name: FORMATTED_LANDMARK_DETAILS, Length: 5362, dtype: int64
# ******************************
# ['READY TO MOVE', 'RESALE']                                                                                                12814
# ['READY TO MOVE', 'RESALE', 'RERA']                                                                                         4251
# ['UNDER CONSTRUCTION', 'NEW BOOKING', 'RERA']                                                                               2708
# ['UNDER CONSTRUCTION', 'RESALE']                                                                                            2296
# ['UNDER CONSTRUCTION', 'RESALE', 'RERA']                                                                                    1951
#                                                                                                                            ...
# ['CORNER PROPERTY', 'NORTH-EAST FACING', 'HHB APPROVED', 'IN GATED COMMUNITY', 'READY TO MOVE', 'RESALE']                      1
# ['CORNER PROPERTY', 'NORTH-EAST FACING', 'AUTHORITY APPROVED', 'IN GATED COMMUNITY', 'READY TO MOVE', 'RESALE', 'RERA']        1
# ['CORNER PROPERTY', 'EAST FACING', 'HUDA APPROVED', 'READY TO MOVE', 'RESALE']                                                 1
# ['HHB APPROVED', 'IN GATED COMMUNITY', 'READY TO MOVE', 'RESALE', 'RERA']                                                      1
# ['EAST FACING', 'READY TO MOVE']                                                                                               1
# Name: SECONDARY_TAGS, Length: 311, dtype: int64
# ******************************
# {'LATITUDE': '78.48667', 'LONGITUDE': '17.38504'}                                                                                      481
# {'LATITUDE': '22.6006912', 'LONGITUDE': '88.4694535'}                                                                                  419
# {'LATITUDE': '17.4359437', 'LONGITUDE': '78.3416731'}                                                                                  291
# {'LATITUDE': '17.4609913', 'LONGITUDE': '78.3532083'}                                                                                  271
# {'LATITUDE': '17.40223', 'LONGITUDE': '78.3444'}                                                                                       198
#                                                                                                                                       ...
# {'LATITUDE': '28.463784', 'LONGITUDE': '77.062503', 'ZOOM_LEVEL': '6', 'SOURCE': 'BUILDING', 'MAP_ACCURACY': '0', 'MAPPED': 'Y'}         1
# {'LATITUDE': '28.428798', 'LONGITUDE': '77.029648', 'ZOOM_LEVEL': '6', 'SOURCE': 'BUILDING', 'MAP_ACCURACY': '0', 'MAPPED': 'Y'}         1
# {'LATITUDE': '28.420544', 'LONGITUDE': '77.092353', 'ZOOM_LEVEL': '14', 'SOURCE': 'BUILDING', 'MAP_ACCURACY': '0', 'MAPPED': 'Y'}        1
# {'LATITUDE': '28.4795247', 'LONGITUDE': '76.9688517', 'ZOOM_LEVEL': '14', 'SOURCE': 'VERIFIED', 'MAP_ACCURACY': '0', 'MAPPED': 'Y'}      1
# {'LATITUDE': '17.424037', 'LONGITUDE': '78.450561'}                                                                                      1
# Name: MAP_DETAILS, Length: 10201, dtype: int64
# ******************************
# N                                                                                         8293
# 23,24,5,17,6,19,20,21                                                                     2464
# 23,24,26,5                                                                                1818
# 44,23,45,24,46,47,25,26,28,29,30,31,10,32,33,12,17,39,19,1,3,5,6,8,9,40,41,20,42,21,43     546
# 23,24,25,26,5,6,19,8                                                                       296
#                                                                                           ...
# 12,23,24,25,47,26,17,19,1,2,3,40,30,41,42,21,32                                              1
# 12,23,47,25,26,17,19,1,3,8,9,40,41,30,42,21,32                                               1
# 12,23,47,25,26,17,19,1,3,9,40,30,41,42,21                                                    1
# 23,12,24,25,47,26,17,19,1,3,8,9,40,30,41,42,21,32                                            1
# 44,23,5,39,19,9,40,21                                                                        1
# Name: FEATURES, Length: 13169, dtype: int64
# ******************************
# On Request               325
# on request               307
# Prestige High Fields     238
# Emaar Digihomes          134
# Aparna Sarovar Zenith    103
#                         ...
# Zolo Orchid Enclave        1
# Zolo Mayuresh Sristhi      1
# Zolo Montego               1
# Zolo Milan                 1
# Pavan Heights              1
# Name: BUILDING_NAME, Length: 9850, dtype: int64
# ******************************
# 1       9020
# 2       3475
# 3       3051
# 4       2362
# 5       1532
#         ...
# 4.0        1
# 6.0        1
# 13.0       1
# 25.0       1
# 56         1
# Name: FLOOR_NUM, Length: 79, dtype: int64
# ******************************
# On Request                                 327
# on request                                 309
# Prestige High Fields                       238
# Emaar Digihomes                            134
# Aparna Sarovar Zenith                      103
#                                           ...
# jari mari cottage room num 7..1st floor      1
# Hi Tech Luxus Tower                          1
# Karnani CHS                                  1
# NIRALA                                       1
# Pavan Heights                                1
# Name: PROP_NAME, Length: 9854, dtype: int64
# ******************************
# Price on Request    394
# 2 Cr                285
# 1.5 Cr              279
# 1.3 Cr              272
# 1.1 Cr              272
#                    ...
# 18.92 Cr              1
# 7.49  - 8.15 Cr       1
# 69.75  - 78.75 L      1
# 49.75  - 50 L         1
# 31.25 L               1
# Name: PRICE, Length: 6452, dtype: int64
# ******************************
# 1800 sq.ft.        794
# 1350 sq.ft.        572
# 2700 sq.ft.        412
# 1200 sq.ft.        410
# 1000 sq.ft.        344
#                   ...
# 584-597  sq.ft.      1
# 605-731  sq.ft.      1
# 550-641  sq.ft.      1
# 648-651  sq.ft.      1
# 2219 sq.ft.          1
# Name: AREA, Length: 5469, dtype: int64
# ******************************

# %%
df.describe().T
# Out:
#                         count           mean           std  min     25%  \
# PRICE_PER_UNIT_AREA   38500.0  118496.796961  4.385489e+06  0.0  4166.0
# TRANSACT_TYPE         31987.0       1.204896  4.036317e-01  1.0     1.0
# OWNTYPE               38500.0       0.898857  5.424917e-01  0.0     1.0
# PRICE_SQFT            38500.0  118482.531065  4.385488e+06  0.0  4166.0
# BALCONY_NUM           28503.0       1.947339  1.197352e+00  0.0     1.0
# AGE                   38500.0       3.136078  2.182688e+00  0.0     1.0
# BEDROOM_NUM           34946.0       2.835375  1.616395e+00  1.0     2.0
# TOTAL_FLOOR           37848.0      14.942798  1.350355e+01  0.0     4.0
# FURNISH               38500.0       1.990234  1.601711e+00  0.0     0.0
# TOTAL_LANDMARK_COUNT  36359.0      25.038807  1.769461e+01  1.0    10.0
# FACING                38500.0       2.833636  2.320741e+00  0.0     0.0
#
#                          50%       75%          max
# PRICE_PER_UNIT_AREA   8974.0  17355.75  600000000.0
# TRANSACT_TYPE            1.0      1.00          2.0
# OWNTYPE                  1.0      1.00          4.0
# PRICE_SQFT            8974.0  17352.50  600000000.0
# BALCONY_NUM              2.0      3.00          4.0
# AGE                      3.0      5.00          6.0
# BEDROOM_NUM              3.0      3.00         77.0
# TOTAL_FLOOR             12.0     22.00        117.0
# FURNISH                  2.0      4.00          4.0
# TOTAL_LANDMARK_COUNT    15.0     47.00         50.0
# FACING                   3.0      5.00          8.0

# %%
df.describe(include="object")
# Out:
#                 PROPERTY_TYPE  \
# count                   38500
# unique                      8
# top     Residential Apartment
# freq                    28548
#
#                                               DESCRIPTION  \
# count                                               38500
# unique                                              35015
# top     Its on main road. Sarrounding villas & apartme...
# freq                                                   92
#
#                   PROP_HEADING   AMENITIES  \
# count                    38500       30483
# unique                    5967       14732
# top     3 BHK Flat in New Town  5,23,24,26
# freq                       655        1818
#
#                                                  location     CITY  \
# count                                               38500    38500
# unique                                              16614       17
# top     {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...  Gurgaon
# freq                                                 1077    10704
#
#        SOCIETY_NAME    PROP_ID PREFERENCE  \
# count         33482      38500      38500
# unique         9855      38487          3
# top      On Request  N70806490          S
# freq            329          2      32008
#
#                                FORMATTED_LANDMARK_DETAILS  \
# count                                               36359
# unique                                               5362
# top     [{'category': 'MetroStation', 'text': '1 Metro...
# freq                                                  519
#
#                      SECONDARY_TAGS  \
# count                         38500
# unique                          311
# top     ['READY TO MOVE', 'RESALE']
# freq                          12814
#
#                                               MAP_DETAILS FEATURES  \
# count                                               38500    38500
# unique                                              10201    13169
# top     {'LATITUDE': '78.48667', 'LONGITUDE': '17.38504'}        N
# freq                                                  481     8293
#
#        BUILDING_NAME FLOOR_NUM   PROP_NAME             PRICE         AREA
# count          33469     31979       33482             38500        38500
# unique          9850        79        9854              6452         5469
# top       On Request         1  On Request  Price on Request  1800 sq.ft.
# freq             325      9020         327               394          794

# %%
df.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA              0
# PROPERTY_TYPE                    0
# DESCRIPTION                      0
# TRANSACT_TYPE                 6513
# PROP_HEADING                     0
# AMENITIES                     8017
# OWNTYPE                          0
# PRICE_SQFT                       0
# BALCONY_NUM                   9997
# AGE                              0
# location                         0
# CITY                             0
# BEDROOM_NUM                   3554
# TOTAL_FLOOR                    652
# FURNISH                          0
# SOCIETY_NAME                  5018
# PROP_ID                          0
# PREFERENCE                       0
# FORMATTED_LANDMARK_DETAILS    2141
# SECONDARY_TAGS                   0
# MAP_DETAILS                      0
# FEATURES                         0
# BUILDING_NAME                 5031
# TOTAL_LANDMARK_COUNT          2141
# FLOOR_NUM                     6521
# PROP_NAME                     5018
# FACING                           0
# PRICE                            0
# AREA                             0
# dtype: int64

# %%
impute=KNNImputer()

# %%
for i in df.select_dtypes(include="number").columns:
    df[i]=impute.fit_transform(df[[i]])

# %%
df.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA              0
# PROPERTY_TYPE                    0
# DESCRIPTION                      0
# TRANSACT_TYPE                    0
# PROP_HEADING                     0
# AMENITIES                     8017
# OWNTYPE                          0
# PRICE_SQFT                       0
# BALCONY_NUM                      0
# AGE                              0
# location                         0
# CITY                             0
# BEDROOM_NUM                      0
# TOTAL_FLOOR                      0
# FURNISH                          0
# SOCIETY_NAME                  5018
# PROP_ID                          0
# PREFERENCE                       0
# FORMATTED_LANDMARK_DETAILS    2141
# SECONDARY_TAGS                   0
# MAP_DETAILS                      0
# FEATURES                         0
# BUILDING_NAME                 5031
# TOTAL_LANDMARK_COUNT             0
# FLOOR_NUM                     6521
# PROP_NAME                     5018
# FACING                           0
# PRICE                            0
# AREA                             0
# dtype: int64

# %%
df.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA              0
# PROPERTY_TYPE                    0
# DESCRIPTION                      0
# TRANSACT_TYPE                    0
# PROP_HEADING                     0
# AMENITIES                     8017
# OWNTYPE                          0
# PRICE_SQFT                       0
# BALCONY_NUM                      0
# AGE                              0
# location                         0
# CITY                             0
# BEDROOM_NUM                      0
# TOTAL_FLOOR                      0
# FURNISH                          0
# SOCIETY_NAME                  5018
# PROP_ID                          0
# PREFERENCE                       0
# FORMATTED_LANDMARK_DETAILS    2141
# SECONDARY_TAGS                   0
# MAP_DETAILS                      0
# FEATURES                         0
# BUILDING_NAME                 5031
# TOTAL_LANDMARK_COUNT             0
# FLOOR_NUM                     6521
# PROP_NAME                     5018
# FACING                           0
# PRICE                            0
# AREA                             0
# dtype: int64

# %%
df["SOCIETY_NAME"]=df["SOCIETY_NAME"].fillna("unknown")
df["FLOOR_NUM"]=df["FLOOR_NUM"].fillna("unknown")

# %%
df = df.fillna(method='ffill')  # Forward fill missing values

# %%
df = df.fillna(method='ffill')  # Forward fill missing values

# %%
df['BALCONY_NUM'].fillna(-1, inplace=True)  # Example: Fill with -1 or another appropriate value

# %%
df.replace([np.inf, -np.inf], np.nan, inplace=True)

# %%
df.fillna(method='ffill', inplace=True)  # Reapply forward fill if needed

# %%
df.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA           0
# PROPERTY_TYPE                 0
# DESCRIPTION                   0
# TRANSACT_TYPE                 0
# PROP_HEADING                  0
# AMENITIES                     0
# OWNTYPE                       0
# PRICE_SQFT                    0
# BALCONY_NUM                   0
# AGE                           0
# location                      0
# CITY                          0
# BEDROOM_NUM                   0
# TOTAL_FLOOR                   0
# FURNISH                       0
# SOCIETY_NAME                  0
# PROP_ID                       0
# PREFERENCE                    0
# FORMATTED_LANDMARK_DETAILS    0
# SECONDARY_TAGS                0
# MAP_DETAILS                   0
# FEATURES                      0
# BUILDING_NAME                 0
# TOTAL_LANDMARK_COUNT          0
# FLOOR_NUM                     0
# PROP_NAME                     0
# FACING                        0
# PRICE                         0
# AREA                          0
# dtype: int64

# %%
df.to_csv('real_estate_data.csv', index=False)

# %% [markdown]
# we have successfully handles missing values and duplicates , as i loaded the data into excel i realized i need to remove some
# not so important columns and divide some columns into two
# moreover we have to trim the values for them to function properly

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38500 entries, 0 to 38501
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38500 non-null  float64
#  1   PROPERTY_TYPE               38500 non-null  object
#  2   DESCRIPTION                 38500 non-null  object
#  3   TRANSACT_TYPE               38500 non-null  float64
#  4   PROP_HEADING                38500 non-null  object
#  5   AMENITIES                   38500 non-null  object
#  6   OWNTYPE                     38500 non-null  float64
#  7   PRICE_SQFT                  38500 non-null  float64
#  8   BALCONY_NUM                 38500 non-null  float64
#  9   AGE                         38500 non-null  float64
#  10  location                    38500 non-null  object
#  11  CITY                        38500 non-null  object
#  12  BEDROOM_NUM                 38500 non-null  float64
#  13  TOTAL_FLOOR                 38500 non-null  float64
#  14  FURNISH                     38500 non-null  float64
#  15  SOCIETY_NAME                38500 non-null  object
#  16  PROP_ID                     38500 non-null  object
#  17  PREFERENCE                  38500 non-null  object
#  18  FORMATTED_LANDMARK_DETAILS  38500 non-null  object
#  19  SECONDARY_TAGS              38500 non-null  object
#  20  MAP_DETAILS                 38500 non-null  object
#  21  FEATURES                    38500 non-null  object
#  22  BUILDING_NAME               38500 non-null  object
#  23  TOTAL_LANDMARK_COUNT        38500 non-null  float64
#  24  FLOOR_NUM                   38500 non-null  object
#  25  PROP_NAME                   38500 non-null  object
#  26  FACING                      38500 non-null  float64
#  27  PRICE                       38500 non-null  object
#  28  AREA                        38500 non-null  object
# dtypes: float64(11), object(18)
# memory usage: 8.8+ MB

# %%
df = df.drop(columns=['FEATURES'])
df = df.drop(columns=['AMENITIES'])
df = df.drop(columns=['FURNISH'])
df = df.drop(columns=['FACING'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38500 entries, 0 to 38501
# Data columns (total 25 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38500 non-null  float64
#  1   PROPERTY_TYPE               38500 non-null  object
#  2   DESCRIPTION                 38500 non-null  object
#  3   TRANSACT_TYPE               38500 non-null  float64
#  4   PROP_HEADING                38500 non-null  object
#  5   OWNTYPE                     38500 non-null  float64
#  6   PRICE_SQFT                  38500 non-null  float64
#  7   BALCONY_NUM                 38500 non-null  float64
#  8   AGE                         38500 non-null  float64
#  9   location                    38500 non-null  object
#  10  CITY                        38500 non-null  object
#  11  BEDROOM_NUM                 38500 non-null  float64
#  12  TOTAL_FLOOR                 38500 non-null  float64
#  13  SOCIETY_NAME                38500 non-null  object
#  14  PROP_ID                     38500 non-null  object
#  15  PREFERENCE                  38500 non-null  object
#  16  FORMATTED_LANDMARK_DETAILS  38500 non-null  object
#  17  SECONDARY_TAGS              38500 non-null  object
#  18  MAP_DETAILS                 38500 non-null  object
#  19  BUILDING_NAME               38500 non-null  object
#  20  TOTAL_LANDMARK_COUNT        38500 non-null  float64
#  21  FLOOR_NUM                   38500 non-null  object
#  22  PROP_NAME                   38500 non-null  object
#  23  PRICE                       38500 non-null  object
#  24  AREA                        38500 non-null  object
# dtypes: float64(9), object(16)
# memory usage: 7.6+ MB

# %%
split_columns = df['SECONDARY_TAGS'].str.split(',', expand=True)

# %%
expected_columns = ['status', 'ownership_type', 'rera/hera']
for i, col in enumerate(expected_columns):
    if i < split_columns.shape[1]:
        df[col] = split_columns[i]
    else:
        df[col] = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38500 entries, 0 to 38501
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38500 non-null  float64
#  1   PROPERTY_TYPE               38500 non-null  object
#  2   DESCRIPTION                 38500 non-null  object
#  3   TRANSACT_TYPE               38500 non-null  float64
#  4   PROP_HEADING                38500 non-null  object
#  5   OWNTYPE                     38500 non-null  float64
#  6   PRICE_SQFT                  38500 non-null  float64
#  7   BALCONY_NUM                 38500 non-null  float64
#  8   AGE                         38500 non-null  float64
#  9   location                    38500 non-null  object
#  10  CITY                        38500 non-null  object
#  11  BEDROOM_NUM                 38500 non-null  float64
#  12  TOTAL_FLOOR                 38500 non-null  float64
#  13  SOCIETY_NAME                38500 non-null  object
#  14  PROP_ID                     38500 non-null  object
#  15  PREFERENCE                  38500 non-null  object
#  16  FORMATTED_LANDMARK_DETAILS  38500 non-null  object
#  17  SECONDARY_TAGS              38500 non-null  object
#  18  MAP_DETAILS                 38500 non-null  object
#  19  BUILDING_NAME               38500 non-null  object
#  20  TOTAL_LANDMARK_COUNT        38500 non-null  float64
#  21  FLOOR_NUM                   38500 non-null  object
#  22  PROP_NAME                   38500 non-null  object
#  23  PRICE                       38500 non-null  object
#  24  AREA                        38500 non-null  object
#  25  status                      38500 non-null  object
#  26  ownership_type              35809 non-null  object
#  27  rera/hera                   17107 non-null  object
# dtypes: float64(9), object(19)
# memory usage: 8.5+ MB

# %%
df.isnull().sum()/df.shape[0]*100
# Out:
# PRICE_PER_UNIT_AREA            0.000000
# PROPERTY_TYPE                  0.000000
# DESCRIPTION                    0.000000
# TRANSACT_TYPE                  0.000000
# PROP_HEADING                   0.000000
# OWNTYPE                        0.000000
# PRICE_SQFT                     0.000000
# BALCONY_NUM                    0.000000
# AGE                            0.000000
# location                       0.000000
# CITY                           0.000000
# BEDROOM_NUM                    0.000000
# TOTAL_FLOOR                    0.000000
# SOCIETY_NAME                   0.000000
# PROP_ID                        0.000000
# PREFERENCE                     0.000000
# FORMATTED_LANDMARK_DETAILS     0.000000
# SECONDARY_TAGS                 0.000000
# MAP_DETAILS                    0.000000
# BUILDING_NAME                  0.000000
# TOTAL_LANDMARK_COUNT           0.000000
# FLOOR_NUM                      0.000000
# PROP_NAME                      0.000000
# PRICE                          0.000000
# AREA                           0.000000
# status                         0.000000
# ownership_type                 6.989610
# rera/hera                     55.566234
# dtype: float64

# %%
df = df.drop(columns=['SECONDARY_TAGS'])
df = df.drop(columns=['rera/hera'])

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38500 entries, 0 to 38501
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38500 non-null  float64
#  1   PROPERTY_TYPE               38500 non-null  object
#  2   DESCRIPTION                 38500 non-null  object
#  3   TRANSACT_TYPE               38500 non-null  float64
#  4   PROP_HEADING                38500 non-null  object
#  5   OWNTYPE                     38500 non-null  float64
#  6   PRICE_SQFT                  38500 non-null  float64
#  7   BALCONY_NUM                 38500 non-null  float64
#  8   AGE                         38500 non-null  float64
#  9   location                    38500 non-null  object
#  10  CITY                        38500 non-null  object
#  11  BEDROOM_NUM                 38500 non-null  float64
#  12  TOTAL_FLOOR                 38500 non-null  float64
#  13  SOCIETY_NAME                38500 non-null  object
#  14  PROP_ID                     38500 non-null  object
#  15  PREFERENCE                  38500 non-null  object
#  16  FORMATTED_LANDMARK_DETAILS  38500 non-null  object
#  17  MAP_DETAILS                 38500 non-null  object
#  18  BUILDING_NAME               38500 non-null  object
#  19  TOTAL_LANDMARK_COUNT        38500 non-null  float64
#  20  FLOOR_NUM                   38500 non-null  object
#  21  PROP_NAME                   38500 non-null  object
#  22  PRICE                       38500 non-null  object
#  23  AREA                        38500 non-null  object
#  24  status                      38500 non-null  object
#  25  ownership_type              35809 non-null  object
# dtypes: float64(9), object(17)
# memory usage: 7.9+ MB

# %%
df['ownership_type'].fillna('for rent', inplace=True)

# %%
# Out:
# PRICE_PER_UNIT_AREA           0
# PROPERTY_TYPE                 0
# DESCRIPTION                   0
# TRANSACT_TYPE                 0
# PROP_HEADING                  0
# OWNTYPE                       0
# PRICE_SQFT                    0
# BALCONY_NUM                   0
# AGE                           0
# location                      0
# CITY                          0
# BEDROOM_NUM                   0
# TOTAL_FLOOR                   0
# SOCIETY_NAME                  0
# PROP_ID                       0
# PREFERENCE                    0
# FORMATTED_LANDMARK_DETAILS    0
# MAP_DETAILS                   0
# BUILDING_NAME                 0
# TOTAL_LANDMARK_COUNT          0
# FLOOR_NUM                     0
# PROP_NAME                     0
# PRICE                         0
# AREA                          0
# status                        0
# ownership_type                0
# dtype: int64

# %%
furnish_data = pd.read_csv('real_estate_data.csv', usecols=['FURNISH'])

# Add the 'furnish' column back to the DataFrame
df['FURNISH'] = furnish_data['FURNISH']

# %%
# Out:
# PRICE_PER_UNIT_AREA           0
# PROPERTY_TYPE                 0
# DESCRIPTION                   0
# TRANSACT_TYPE                 0
# PROP_HEADING                  0
# OWNTYPE                       0
# PRICE_SQFT                    0
# BALCONY_NUM                   0
# AGE                           0
# location                      0
# CITY                          0
# BEDROOM_NUM                   0
# TOTAL_FLOOR                   0
# SOCIETY_NAME                  0
# PROP_ID                       0
# PREFERENCE                    0
# FORMATTED_LANDMARK_DETAILS    0
# MAP_DETAILS                   0
# BUILDING_NAME                 0
# TOTAL_LANDMARK_COUNT          0
# FLOOR_NUM                     0
# PROP_NAME                     0
# PRICE                         0
# AREA                          0
# status                        0
# ownership_type                0
# FURNISH                       2
# dtype: int64

# %%
split_columns = df['MAP_DETAILS'].str.split(',', expand=True)

# %%
expected_columns = ['LATTITUDE','LONGITUDE']
for i, col in enumerate(expected_columns):
    if i < split_columns.shape[1]:
        df[col] = split_columns[i]
    else:
        df[col] = None

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38500 entries, 0 to 38501
# Data columns (total 29 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38500 non-null  float64
#  1   PROPERTY_TYPE               38500 non-null  object
#  2   DESCRIPTION                 38500 non-null  object
#  3   TRANSACT_TYPE               38500 non-null  float64
#  4   PROP_HEADING                38500 non-null  object
#  5   OWNTYPE                     38500 non-null  float64
#  6   PRICE_SQFT                  38500 non-null  float64
#  7   BALCONY_NUM                 38500 non-null  float64
#  8   AGE                         38500 non-null  float64
#  9   location                    38500 non-null  object
#  10  CITY                        38500 non-null  object
#  11  BEDROOM_NUM                 38500 non-null  float64
#  12  TOTAL_FLOOR                 38500 non-null  float64
#  13  SOCIETY_NAME                38500 non-null  object
#  14  PROP_ID                     38500 non-null  object
#  15  PREFERENCE                  38500 non-null  object
#  16  FORMATTED_LANDMARK_DETAILS  38500 non-null  object
#  17  MAP_DETAILS                 38500 non-null  object
#  18  BUILDING_NAME               38500 non-null  object
#  19  TOTAL_LANDMARK_COUNT        38500 non-null  float64
#  20  FLOOR_NUM                   38500 non-null  object
#  21  PROP_NAME                   38500 non-null  object
#  22  PRICE                       38500 non-null  object
#  23  AREA                        38500 non-null  object
#  24  status                      38500 non-null  object
#  25  ownership_type              38500 non-null  object
#  26  FURNISH                     38498 non-null  float64
#  27  LATTITUDE                   38500 non-null  object
#  28  LONGITUDE                   38500 non-null  object
# dtypes: float64(10), object(19)
# memory usage: 8.8+ MB

# %%
df = df.drop(columns=['MAP_DETAILS'])

# %%
df = df.drop(columns=['TRANSACT_TYPE'])

# %%
df.to_csv('working1.csv', index=False)

# %%
df.head()
# Out:
#    PRICE_PER_UNIT_AREA          PROPERTY_TYPE  \
# 0               3662.0  Residential Apartment
# 1              10500.0  Residential Apartment
# 2               8900.0  Residential Apartment
# 3                208.0       Residential Land
# 4               5215.0  Residential Apartment
#
#                                          DESCRIPTION  \
# 0  Book your 2 BHK flat in Srijan Star Swapno Pur...
# 1  Make Natural Quest your next home. This projec...
# 2  Book your 3 BHK apartment in Garia, Kolkata So...
# 3  Dev bhumi in joka, kolkata south by ocean land...
# 4  Let your dream of owning a flat come true with...
#
#                       PROP_HEADING  OWNTYPE  PRICE_SQFT  BALCONY_NUM  AGE  \
# 0             2 BHK Flat in Amtala      1.0      3662.0     1.947339  5.0
# 1          3 BHK Flat in EM Bypass      1.0     10500.0     1.947339  5.0
# 2              3 BHK Flat in Garia      1.0      8900.0     1.947339  5.0
# 3  Residential land / Plot in Joka      1.0       208.0     1.947339  0.0
# 4               3 BHK Flat in Joka      1.0      5215.0     1.947339  5.0
#
#                                             location           CITY  ...  \
# 0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...  Kolkata South  ...
# 1  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...  Kolkata South  ...
# 2  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...  Kolkata South  ...
# 3  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...  Kolkata South  ...
# 4  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...  Kolkata South  ...
#
#    TOTAL_LANDMARK_COUNT  FLOOR_NUM                 PROP_NAME            PRICE  \
# 0                   2.0          1  Srijan Star Swapno Puron   19.1 L Onwards
# 1                   9.0          1             Natural Quest  1.17  - 1.18 Cr
# 2                   6.0          1   Ganguly 4Sight Eminence  1.22  - 1.35 Cr
# 3                  13.0    unknown                 Dev Bhumi    1.5  - 5.99 L
# 4                  11.0          1                 DTC Sojon       60  - 75 L
#
#                 AREA                 status   ownership_type  FURNISH  \
# 0    518-623  sq.ft.  ['UNDER CONSTRUCTION'    'NEW BOOKING'      0.0
# 1  1110-1121  sq.ft.  ['UNDER CONSTRUCTION'     'NEW LAUNCH'      0.0
# 2  1376-1516  sq.ft.  ['UNDER CONSTRUCTION'     'NEW LAUNCH'      0.0
# 3   720-2880  sq.ft.       ['READY TO MOVE'   'NEW BOOKING']      0.0
# 4  1130-1460  sq.ft.  ['UNDER CONSTRUCTION'   'NEW BOOKING']      0.0
#
#                    LATTITUDE                    LONGITUDE
# 0   {'LATITUDE': '22.364447'    'LONGITUDE': '88.274642'}
# 1   {'LATITUDE': '22.518795'    'LONGITUDE': '88.388439'}
# 2  {'LATITUDE': '22.5137646'   'LONGITUDE': '88.3666797'}
# 3    {'LATITUDE': '22.45383'    'LONGITUDE': '88.249572'}
# 4    {'LATITUDE': '22.44213'     'LONGITUDE': '88.29551'}
#
# [5 rows x 27 columns]

# %%
def clean_latitude(lat_str):
    latitude = lat_str.split("{'LATITUDE': '")[1].split("'")[0]
    return float(latitude)

# %%
df['LATTITUDE'] = df['LATTITUDE'].apply(clean_latitude)

# %%
def clean_LONGITUDE(lat_str):
    LONGITUDE = lat_str.split("'LONGITUDE': '")[1].split("'")[0]
    return float(LONGITUDE)
df['LONGITUDE'] = df['LONGITUDE'].apply(clean_LONGITUDE)

# %% [markdown]
# i accidently excetued the following comment again so they showed error , but this was the code to trim and split the prop head column

# %%
# df[['Property_Type', 'Location']] = df['PROP_HEADING'].str.extract(r'(.+?)(?:in\s)(.+)')

# %%
# df = df.drop(columns=['PROP_HEADING'])

# %%
df.rename(columns={'location': 'locality'}, inplace=True)

# %%
df.head(2)
# Out:
#    PRICE_PER_UNIT_AREA          PROPERTY_TYPE  \
# 0               3662.0  Residential Apartment
# 1              10500.0  Residential Apartment
#
#                                          DESCRIPTION  OWNTYPE  PRICE_SQFT  \
# 0  Book your 2 BHK flat in Srijan Star Swapno Pur...      1.0      3662.0
# 1  Make Natural Quest your next home. This projec...      1.0     10500.0
#
#    BALCONY_NUM  AGE                                           locality  \
# 0     1.947339  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 1     1.947339  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
#
#             CITY  BEDROOM_NUM  ...                 PROP_NAME            PRICE  \
# 0  Kolkata South          2.0  ...  Srijan Star Swapno Puron   19.1 L Onwards
# 1  Kolkata South          3.0  ...             Natural Quest  1.17  - 1.18 Cr
#
#                 AREA                 status  ownership_type FURNISH  \
# 0    518-623  sq.ft.  ['UNDER CONSTRUCTION'   'NEW BOOKING'     0.0
# 1  1110-1121  sq.ft.  ['UNDER CONSTRUCTION'    'NEW LAUNCH'     0.0
#
#    LATTITUDE  LONGITUDE Property_Type   Location
# 0  22.364447  88.274642   2 BHK Flat      Amtala
# 1  22.518795  88.388439   3 BHK Flat   EM Bypass
#
# [2 rows x 28 columns]

# %%
def extract_value(s):
    if isinstance(s, str):
        parts = s.split("'")
        # Check if the list has enough elements
        if len(parts) > 1:
            return parts[1]
    # Return the original value if it's not a string or doesn't have the expected format
    return s

# Apply the function to the column
df['status'] = df['status'].apply(extract_value)

# %%
df['ownership_type'] = df['ownership_type'].apply(extract_value)

# %%
df.tail()
# Out:
#        PRICE_PER_UNIT_AREA              PROPERTY_TYPE  \
# 38497              19000.0           Residential Land
# 38498              11000.0           Residential Land
# 38499                 15.0  Independent/Builder Floor
# 38500               6400.0      Residential Apartment
# 38501               5328.0      Residential Apartment
#
#                                              DESCRIPTION  OWNTYPE  PRICE_SQFT  \
# 38497  North and east facing approved open plots avai...      1.0     19000.0
# 38498  North and east facing approved open plots avai...      1.0     11000.0
# 38499  2bhk, independent building floor available for...      0.0        15.0
# 38500  A project by sora constructions\nGhmc & rera a...      1.0      6400.0
# 38501  Grama panchayithi approval\nProject located at...      1.0      5328.0
#
#        BALCONY_NUM  AGE                                           locality  \
# 38497          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38498          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38499          1.0  1.0  {'CITY': '268', 'CITY_NAME': 'Secunderabad', '...
# 38500          2.0  5.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38501          2.0  6.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
#
#                CITY  BEDROOM_NUM  ...           PROP_NAME    PRICE  \
# 38497     Hyderabad     2.835375  ...                 kgn  31.73 L
# 38498     Hyderabad     2.835375  ...                 kgn     33 L
# 38499  Secunderabad     2.000000  ...                 kgn   15,000
# 38500     Hyderabad     3.000000  ...  Greenwoods Project  1.02 Cr
# 38501     Hyderabad     2.000000  ...       Pavan Heights     65 L
#
#       AREA IN SQFT              status      ownership_type FURNISH  LATTITUDE  \
# 38497  1503 sq.ft.         EAST FACING  AUTHORITY APPROVED     4.0  17.463918
# 38498  2700 sq.ft.         EAST FACING  AUTHORITY APPROVED     2.0  16.985875
# 38499  1000 sq.ft.      FOR SINGLE MEN    FOR SINGLE WOMEN     2.0  17.465387
# 38500  1600 sq.ft.  UNDER CONSTRUCTION              RESALE     NaN  17.470780
# 38501  1220 sq.ft.       READY TO MOVE              RESALE     NaN  17.401162
#
#        LONGITUDE                     Property_Type     Location
# 38497  78.624229          Residential land / Plot     Ghatkesar
# 38498  78.499864          Residential land / Plot       Kadthal
# 38499  78.478036  2 BHK Independent Builder Floor    Bowenpally
# 38500  78.306680                       3 BHK Flat   Nallagandla
# 38501  78.375690                       2 BHK Flat     Manikonda
#
# [5 rows x 28 columns]

# %%
df['BALCONY_NUM'] = df['BALCONY_NUM'].round()

# %%
df.rename(columns={'AREA': 'AREA IN SQFT'}, inplace=True)

# %%
def process_area(area_str):
    if isinstance(area_str, str):
        # Remove 'sq.ft.' from the string
        area_str = area_str.replace(' sq.ft.', '')
        
        # Handle range of values
        if '-' in area_str:
            # Split the range and calculate the average
            lower, upper = map(float, area_str.split('-'))
            return (lower + upper) / 2
        else:
            # If there's no range, just return the value
            return float(area_str)
    return np.nan

# Apply the function to the 'AREA IN SQFT' column
df['AREA IN SQFT'] = df['AREA IN SQFT'].apply(process_area)

# %%
df['BEDROOM_NUM'] = df['BEDROOM_NUM'].round()

# %%
df.tail(30)
# Out:
#        PRICE_PER_UNIT_AREA              PROPERTY_TYPE  \
# 38472              17333.0           Residential Land
# 38473              17333.0           Residential Land
# 38474              17333.0           Residential Land
# 38475              17333.0           Residential Land
# 38476              17333.0           Residential Land
# 38477              17333.0           Residential Land
# 38478              17333.0           Residential Land
# 38479              15990.0           Residential Land
# 38480              15999.0           Residential Land
# 38481              15999.0           Residential Land
# 38482               7999.0           Residential Land
# 38483               8000.0           Residential Land
# 38484              17000.0           Residential Land
# 38485               8000.0           Residential Land
# 38486              15999.0           Residential Land
# 38487               7999.0           Residential Land
# 38488              12500.0           Residential Land
# 38489              17000.0           Residential Land
# 38490              12500.0           Residential Land
# 38491              12500.0           Residential Land
# 38492              17000.0           Residential Land
# 38493              12500.0           Residential Land
# 38494              14000.0           Residential Land
# 38495              11000.0           Residential Land
# 38496              11000.0           Residential Land
# 38497              19000.0           Residential Land
# 38498              11000.0           Residential Land
# 38499                 15.0  Independent/Builder Floor
# 38500               6400.0      Residential Apartment
# 38501               5328.0      Residential Apartment
#
#                                              DESCRIPTION  OWNTYPE  PRICE_SQFT  \
# 38472  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38473  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38474  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38475  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38476  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38477  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38478  Hmda approved plot for sale near to main road ...      1.0     17333.0
# 38479  North and east facing approved open plots avai...      1.0     15990.0
# 38480  North and east facing approved open plots avai...      1.0     15999.0
# 38481  North and east facing approved open plots avai...      1.0     15999.0
# 38482  North and east facing approved open plots avai...      1.0      7999.0
# 38483  North and east facing approved open plots avai...      1.0      8000.0
# 38484  North and east facing approved open plots avai...      1.0     17000.0
# 38485  North and east facing approved open plots avai...      1.0      8000.0
# 38486  North and east facing approved open plots avai...      1.0     15999.0
# 38487  North and east facing approved open plots avai...      1.0      7999.0
# 38488  North and east facing approved open plots avai...      1.0     12500.0
# 38489  North and east facing approved open plots avai...      1.0     17000.0
# 38490  North and east facing approved open plots avai...      1.0     12500.0
# 38491  North and east facing approved open plots avai...      1.0     12500.0
# 38492  North and east facing approved open plots avai...      1.0     17000.0
# 38493  North and east facing approved open plots avai...      1.0     12500.0
# 38494  North and east facing approved open plots avai...      1.0     14000.0
# 38495  North and east facing approved open plots avai...      1.0     11000.0
# 38496  North and east facing approved open plots avai...      1.0     11000.0
# 38497  North and east facing approved open plots avai...      1.0     19000.0
# 38498  North and east facing approved open plots avai...      1.0     11000.0
# 38499  2bhk, independent building floor available for...      0.0        15.0
# 38500  A project by sora constructions\nGhmc & rera a...      1.0      6400.0
# 38501  Grama panchayithi approval\nProject located at...      1.0      5328.0
#
#        BALCONY_NUM  AGE                                           locality  \
# 38472          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38473          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38474          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38475          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38476          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38477          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38478          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38479          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38480          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38481          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38482          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38483          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38484          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38485          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38486          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38487          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38488          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38489          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38490          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38491          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38492          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38493          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38494          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38495          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38496          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38497          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38498          2.0  0.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38499          1.0  1.0  {'CITY': '268', 'CITY_NAME': 'Secunderabad', '...
# 38500          2.0  5.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
# 38501          2.0  6.0  {'CITY': '269', 'CITY_NAME': 'Hyderabad', 'BUI...
#
#                CITY  BEDROOM_NUM  ...           PROP_NAME    PRICE  \
# 38472     Hyderabad          3.0  ...                 kgn     26 L
# 38473     Hyderabad          3.0  ...                 kgn     26 L
# 38474     Hyderabad          3.0  ...                 kgn     26 L
# 38475     Hyderabad          3.0  ...                 kgn     26 L
# 38476     Hyderabad          3.0  ...                 kgn     26 L
# 38477     Hyderabad          3.0  ...                 kgn     26 L
# 38478     Hyderabad          3.0  ...                 kgn     26 L
# 38479     Hyderabad          3.0  ...                 kgn  31.98 L
# 38480     Hyderabad          3.0  ...                 kgn     24 L
# 38481     Hyderabad          3.0  ...                 kgn     40 L
# 38482     Hyderabad          3.0  ...                 kgn     16 L
# 38483     Hyderabad          3.0  ...                 kgn     16 L
# 38484     Hyderabad          3.0  ...                 kgn     34 L
# 38485     Hyderabad          3.0  ...                 kgn     16 L
# 38486     Hyderabad          3.0  ...                 kgn  26.72 L
# 38487     Hyderabad          3.0  ...                 kgn     20 L
# 38488     Hyderabad          3.0  ...                 kgn  18.75 L
# 38489     Hyderabad          3.0  ...                 kgn  36.38 L
# 38490     Hyderabad          3.0  ...                 kgn     25 L
# 38491     Hyderabad          3.0  ...                 kgn  22.88 L
# 38492     Hyderabad          3.0  ...                 kgn  31.11 L
# 38493     Hyderabad          3.0  ...                 kgn  31.25 L
# 38494     Hyderabad          3.0  ...                 kgn     21 L
# 38495     Hyderabad          3.0  ...                 kgn     22 L
# 38496     Hyderabad          3.0  ...                 kgn  18.37 L
# 38497     Hyderabad          3.0  ...                 kgn  31.73 L
# 38498     Hyderabad          3.0  ...                 kgn     33 L
# 38499  Secunderabad          2.0  ...                 kgn   15,000
# 38500     Hyderabad          3.0  ...  Greenwoods Project  1.02 Cr
# 38501     Hyderabad          2.0  ...       Pavan Heights     65 L
#
#       AREA IN SQFT              status      ownership_type FURNISH  LATTITUDE  \
# 38472       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38473       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38474       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38475       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38476       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38477       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38478       1350.0         EAST FACING  IN GATED COMMUNITY     0.0  17.463918
# 38479       1800.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38480       1350.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38481       2250.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38482       1800.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38483       1800.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38484       1800.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38485       1800.0         EAST FACING  AUTHORITY APPROVED     0.0  17.071390
# 38486       1503.0         EAST FACING       DTCP APPROVED     0.0  17.071390
# 38487       2250.0         EAST FACING       DTCP APPROVED     0.0  17.071390
# 38488       1350.0         EAST FACING       DTCP APPROVED     0.0  17.619700
# 38489       1926.0         EAST FACING       DTCP APPROVED     0.0  17.071390
# 38490       1800.0         EAST FACING       DTCP APPROVED     0.0  17.619700
# 38491       1647.0         EAST FACING  AUTHORITY APPROVED     0.0  17.619700
# 38492       1647.0         EAST FACING       DTCP APPROVED     0.0  17.620662
# 38493       2250.0         EAST FACING       DTCP APPROVED     0.0  17.619700
# 38494       1350.0         EAST FACING  AUTHORITY APPROVED     0.0  17.619700
# 38495       1800.0         EAST FACING  AUTHORITY APPROVED     0.0  16.985875
# 38496       1503.0         EAST FACING  AUTHORITY APPROVED     0.0  16.985875
# 38497       1503.0         EAST FACING  AUTHORITY APPROVED     4.0  17.463918
# 38498       2700.0         EAST FACING  AUTHORITY APPROVED     2.0  16.985875
# 38499       1000.0      FOR SINGLE MEN    FOR SINGLE WOMEN     2.0  17.465387
# 38500       1600.0  UNDER CONSTRUCTION              RESALE     NaN  17.470780
# 38501       1220.0       READY TO MOVE              RESALE     NaN  17.401162
#
#        LONGITUDE                     Property_Type     Location
# 38472  78.624229          Residential land / Plot     Ghatkesar
# 38473  78.624229          Residential land / Plot     Ghatkesar
# 38474  78.624229          Residential land / Plot     Ghatkesar
# 38475  78.624229          Residential land / Plot     Ghatkesar
# 38476  78.624229          Residential land / Plot     Ghatkesar
# 38477  78.624229          Residential land / Plot     Ghatkesar
# 38478  78.624229          Residential land / Plot     Ghatkesar
# 38479  78.205312          Residential land / Plot    Shad nagar
# 38480  78.205312          Residential land / Plot    Shad nagar
# 38481  78.205312          Residential land / Plot    Shad nagar
# 38482  78.205312          Residential land / Plot    Shad nagar
# 38483  78.205312          Residential land / Plot    Shad nagar
# 38484  78.205312          Residential land / Plot    Shad nagar
# 38485  78.205312          Residential land / Plot    Shad nagar
# 38486  78.205312          Residential land / Plot    Shad nagar
# 38487  78.205312          Residential land / Plot    Shad nagar
# 38488  78.082693          Residential land / Plot    Sangareddy
# 38489  78.205312          Residential land / Plot    Shad nagar
# 38490  78.082693          Residential land / Plot    Sangareddy
# 38491  78.082693          Residential land / Plot    Sangareddy
# 38492  77.953509          Residential land / Plot   Sadashivpet
# 38493  78.082693          Residential land / Plot    Sangareddy
# 38494  78.082693          Residential land / Plot    Sangareddy
# 38495  78.499864          Residential land / Plot       Kadthal
# 38496  78.499864          Residential land / Plot       Kadthal
# 38497  78.624229          Residential land / Plot     Ghatkesar
# 38498  78.499864          Residential land / Plot       Kadthal
# 38499  78.478036  2 BHK Independent Builder Floor    Bowenpally
# 38500  78.306680                       3 BHK Flat   Nallagandla
# 38501  78.375690                       2 BHK Flat     Manikonda
#
# [30 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38500 entries, 0 to 38501
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         38500 non-null  float64
#  1   PROPERTY_TYPE               38500 non-null  object
#  2   DESCRIPTION                 38500 non-null  object
#  3   OWNTYPE                     38500 non-null  float64
#  4   PRICE_SQFT                  38500 non-null  float64
#  5   BALCONY_NUM                 38500 non-null  float64
#  6   AGE                         38500 non-null  float64
#  7   locality                    38500 non-null  object
#  8   CITY                        38500 non-null  object
#  9   BEDROOM_NUM                 38500 non-null  float64
#  10  TOTAL_FLOOR                 38500 non-null  float64
#  11  SOCIETY_NAME                38500 non-null  object
#  12  PROP_ID                     38500 non-null  object
#  13  PREFERENCE                  38500 non-null  object
#  14  FORMATTED_LANDMARK_DETAILS  38500 non-null  object
#  15  BUILDING_NAME               38500 non-null  object
#  16  TOTAL_LANDMARK_COUNT        38500 non-null  float64
#  17  FLOOR_NUM                   38500 non-null  object
#  18  PROP_NAME                   38500 non-null  object
#  19  PRICE                       38500 non-null  object
#  20  AREA IN SQFT                38500 non-null  float64
#  21  status                      38500 non-null  object
#  22  ownership_type              38500 non-null  object
#  23  FURNISH                     38498 non-null  float64
#  24  LATTITUDE                   38500 non-null  float64
#  25  LONGITUDE                   38500 non-null  float64
#  26  Property_Type               38500 non-null  object
#  27  Location                    38500 non-null  object
# dtypes: float64(12), object(16)
# memory usage: 8.5+ MB

# %% [markdown]
# realized that making price into one unit format will be trouble with rental and sales both in same database so we made 2 csv one with rentals and other with sales

# %%
df_rentals = df[
    df['PRICE'].str.contains('/bed', case=False, na=False) |
    df['PRICE'].str.contains('Price on request', case=False, na=False) |
    df['PRICE'].str.replace(',', '').str.isnumeric()
]

# %%
# Filter rows where 'PRICE' does not match the rental conditions above
df_sales = df[
    ~df['PRICE'].str.contains('/bed', case=False, na=False) &
    ~df['PRICE'].str.contains('Price on request', case=False, na=False) &
    ~df['PRICE'].str.replace(',', '').str.isnumeric()
]

# %%
df_rentals['PRICE'].str.contains('Price on request', na=False).sum()
# Out:
# 0

# %%
df_rentals.head(30)
# Out:
#      PRICE_PER_UNIT_AREA              PROPERTY_TYPE  \
# 11                   7.0      Residential Apartment
# 24                   7.0      Residential Apartment
# 25                   5.0      Residential Apartment
# 38                   5.0  Independent/Builder Floor
# 130                  5.0    Independent House/Villa
# 142                  0.0      Residential Apartment
# 196                  8.0    Independent House/Villa
# 250                  0.0      Residential Apartment
# 286                  0.0      Residential Apartment
# 290                 16.0      Residential Apartment
# 291                 45.0  Independent/Builder Floor
# 292                 10.0      Residential Apartment
# 293                 10.0    Independent House/Villa
# 295                 10.0    Independent House/Villa
# 300                  2.0    Independent House/Villa
# 315                 30.0      Residential Apartment
# 352                 18.0    Independent House/Villa
# 392                  3.0      Residential Apartment
# 393                 14.0    Independent House/Villa
# 394                  6.0    Independent House/Villa
# 395                  2.0    Independent House/Villa
# 396                 16.0    Independent House/Villa
# 397                 13.0  Independent/Builder Floor
# 398                  3.0    Independent House/Villa
# 399                  5.0    Independent House/Villa
# 400                 10.0      Residential Apartment
# 401                 25.0  Independent/Builder Floor
# 402                 18.0    Independent House/Villa
# 404                  2.0      Residential Apartment
# 409                  2.0    Independent House/Villa
#
#                                            DESCRIPTION  OWNTYPE  PRICE_SQFT  \
# 11   A luxurious pg accommodation is available in t...      0.0         7.0
# 24   Property description designed to suit ones lif...      0.0         7.0
# 25   Pg only for working ladies and girl students.\...      0.0         5.0
# 38   Well maintained & secured pg/paying guest in k...      0.0         5.0
# 130  Pg for boy availaible for rent, market is 2 mi...      0.0         5.0
# 142  Book your 2 BHK apartment in New Town, Kolkata...      1.0         0.0
# 196             This area is very homely and peaceful.      0.0         8.0
# 250  Sapnil Residency offers 1 BHK apartments in No...      1.0         0.0
# 286  Prudent Pragati is a residential project, offe...      1.0         0.0
# 290               Awesome view and wonderful amenities      0.0        16.0
# 291  Independent/builder floor is available for pg....      0.0        45.0
# 292  Best location to access every place in kolkata...      0.0        10.0
# 293  Pg for girls in jadavpur- Food and wifi is inc...      0.0        10.0
# 295  Double sharring/ single room pg for girls at k...      0.0        10.0
# 300  Government registered pg for females and highl...      0.0         2.0
# 315  Kolkata north's most popular society signum wi...      0.0        30.0
# 352  My property is in prime location . 1 min walk ...      0.0        18.0
# 392  24 hours security. Elegant surroundings. Vitri...      0.0         3.0
# 393  Pg is located in a very serene area.Rooms are ...      0.0        14.0
# 394  A tidy, clean girls' pg is available near kabi...      0.0         6.0
# 395  Nandi ladies pg, dum dum station, near bandhu ...      0.0         2.0
# 396  This is a gents stay facility\n2 out of 4 room...      0.0        16.0
# 397  A decent semi-Furnished pg/paying guest in bha...      0.0        13.0
# 398  Near to masterda surya sen metro station , ban...      0.0         3.0
# 399  Nandi ladies pg, 4 shearing bed available, dum...      0.0         5.0
# 400  Apartment available for rent in kasba, kolkata...      0.0        10.0
# 401  My property is situated beside the main road a...      0.0        25.0
# 402  At prof.S home pg accommodation for male stude...      0.0        18.0
# 404  Walking distance from geetanjali metro. Bus st...      0.0         2.0
# 409  Dadu's mess\nBoys' pg\n Type (1)-Rent 2500 \n(...      0.0         2.0
#
#      BALCONY_NUM  AGE                                           locality  \
# 11           1.0  3.0  {'CITY': '30', 'CITY_NAME': 'Kolkata Central',...
# 24           3.0  3.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 25           1.0  2.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 38           1.0  2.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 130          0.0  1.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 142          2.0  5.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 196          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 250          2.0  5.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 286          2.0  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 290          1.0  2.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 291          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 292          1.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 293          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 295          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 300          1.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 315          2.0  6.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 352          2.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 392          1.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 393          0.0  1.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 394          1.0  2.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 395          0.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 396          1.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 397          1.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 398          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 399          0.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 400          1.0  2.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 401          1.0  6.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 402          2.0  3.0  {'CITY': '30', 'CITY_NAME': 'Kolkata Central',...
# 404          1.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 409          0.0  1.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
#
#                 CITY  BEDROOM_NUM  ...                 PROP_NAME  \
# 11   Kolkata Central          4.0  ...    Ganga Jamuna Apartment
# 24      Kolkata East          4.0  ...      Bhariravi apartment
# 25     Kolkata North          3.0  ...  Vijay Lakshmi Apartments
# 38     Kolkata South          4.0  ...       Sunday On The House
# 130    Kolkata South          2.0  ...      Green View Residency
# 142     Kolkata East          2.0  ...                 Woodwinds
# 196    Kolkata South          2.0  ...   Hive Pinnacle Residency
# 250    Kolkata North          1.0  ...          Sapnil Residency
# 286    Kolkata South          1.0  ...           Prudent Pragati
# 290     Kolkata East          1.0  ...           New Town Tower
# 291    Kolkata South          1.0  ...           New Town Tower
# 292    Kolkata North          2.0  ...             Bangur Avenue
# 293    Kolkata South          2.0  ...             Bangur Avenue
# 295    Kolkata South          1.0  ...      Puja Apartment Kasba
# 300    Kolkata South          6.0  ...    Shanti Niketan Complex
# 315    Kolkata North          4.0  ...          Signum  Windmere
# 352    Kolkata South          2.0  ...                  Srijoyee
# 392    Kolkata North          2.0  ...          RDB Regent Pearl
# 393    Kolkata South          2.0  ...          RDB Regent Pearl
# 394    Kolkata South          3.0  ...          RDB Regent Pearl
# 395    Kolkata North          4.0  ...          RDB Regent Pearl
# 396    Kolkata North          1.0  ...          RDB Regent Pearl
# 397    Kolkata South          2.0  ...          RDB Regent Pearl
# 398    Kolkata South          2.0  ...          RDB Regent Pearl
# 399    Kolkata North          2.0  ...          RDB Regent Pearl
# 400    Kolkata South          2.0  ...       jahura bazarsociety
# 401     Kolkata East          5.0  ...       jahura bazarsociety
# 402  Kolkata Central          3.0  ...       jahura bazarsociety
# 404    Kolkata South          2.0  ...                Green View
# 409    Kolkata South          3.0  ...               DADU'S MESS
#
#                 PRICE AREA IN SQFT              status    ownership_type  \
# 11         11,000/Bed       1500.0           FURNISHED       SHARED BY 3
# 24         10,000/Bed       1300.0           FURNISHED       SHARED BY 2
# 25      6,000/Bedroom       1200.0        PRIVATE ROOM          for rent
# 38         10,000/Bed       2000.0           FURNISHED       SHARED BY 3
# 130         3,000/Bed        600.0           FURNISHED       SHARED BY 2
# 142  Price on Request        789.0  UNDER CONSTRUCTION       NEW BOOKING
# 196         5,001/Bed        600.0           FURNISHED       SHARED BY 2
# 250  Price on Request        657.5  UNDER CONSTRUCTION       NEW BOOKING
# 286  Price on Request        713.0  UNDER CONSTRUCTION        NEW LAUNCH
# 290         4,900/Bed        300.0           FURNISHED       SHARED BY 2
# 291         8,000/Bed        160.0         SHARED BY 5          for rent
# 292         7,501/Bed        750.0         SHARED BY 2          for rent
# 293         8,000/Bed        800.0           FURNISHED       SHARED BY 2
# 295         6,200/Bed        600.0           FURNISHED       SHARED BY 2
# 300         5,000/Bed       2000.0           FURNISHED       SHARED BY 2
# 315            45,000       1657.0      FOR SINGLE MEN  FOR SINGLE WOMEN
# 352            18,000        950.0      FOR SINGLE MEN  FOR SINGLE WOMEN
# 392         3,000/Bed        850.0         SHARED BY 2          for rent
# 393         2,800/Bed        200.0           FURNISHED       SHARED BY 2
# 394         4,500/Bed        680.0         SHARED BY 3          for rent
# 395         2,800/Bed       1200.0           FURNISHED       SHARED BY 4
# 396     5,000/Bedroom        300.0           FURNISHED      PRIVATE ROOM
# 397     4,000/Bedroom        300.0        PRIVATE ROOM          for rent
# 398         2,350/Bed        600.0         SHARED BY 2          for rent
# 399         2,850/Bed        500.0           FURNISHED       SHARED BY 4
# 400         3,000/Bed        300.0         SHARED BY 2          for rent
# 401     3,100/Bedroom        120.0           FURNISHED      PRIVATE ROOM
# 402         3,600/Bed        200.0           FURNISHED       SHARED BY 3
# 404         2,500/Bed       1051.0         SHARED BY 2          for rent
# 409         2,500/Bed        900.0         SHARED BY 3          for rent
#
#     FURNISH  LATTITUDE  LONGITUDE                     Property_Type  \
# 11      1.0  22.543910  88.355401                       4 BHK Flat
# 24      1.0  22.581047  88.462231                       4 BHK Flat
# 25      4.0  22.650056  88.441311                       3 BHK Flat
# 38      1.0  22.534637  88.348268  4 BHK Independent Builder Floor
# 130     1.0  22.527344  88.344062                  2 Bedroom House
# 142     0.0  22.592205  88.452142                       2 BHK Flat
# 196     1.0  22.533000  88.359000                  2 Bedroom House
# 250     0.0  22.641617  88.382771                       1 BHK Flat
# 286     0.0  22.434568  88.402079                       1 BHK Flat
# 290     1.0  22.600691  88.469454                       1 BHK Flat
# 291     4.0  22.495000  88.372000  1 BHK Independent Builder Floor
# 292     2.0  22.606173  88.407854                       2 BHK Flat
# 293     1.0  22.495000  88.372000                  2 Bedroom House
# 295     1.0  22.519587  88.376107                  1 Bedroom House
# 300     1.0  22.487844  88.354289                  6 Bedroom House
# 315     2.0  22.698023  88.438331                       4 BHK Flat
# 352     4.0  22.513630  88.388275                  2 Bedroom House
# 392     4.0  22.696866  88.412716                       2 BHK Flat
# 393     1.0  22.502198  88.375414                  2 Bedroom House
# 394     4.0  22.457894  88.383531                  3 Bedroom House
# 395     1.0  22.621122  88.394112                  4 Bedroom House
# 396     1.0  22.595870  88.385700                  1 Bedroom House
# 397     4.0  22.532300  88.342270  2 BHK Independent Builder Floor
# 398     4.0  22.459650  88.365210                  2 Bedroom House
# 399     1.0  22.621056  88.394049                  2 Bedroom House
# 400     4.0  22.519587  88.376107                       2 BHK Flat
# 401     1.0  22.623582  88.441041  5 BHK Independent Builder Floor
# 402     1.0  22.568000  88.372000                  3 Bedroom House
# 404     4.0  22.465030  88.394210                       2 BHK Flat
# 409     4.0  22.495000  88.372000                  3 Bedroom House
#
#                Location
# 11   Shakespeare Sarani
# 24        Action Area 1
# 25              Dum Dum
# 38      Jadubabur Bazar
# 130           Patuapara
# 142            New Town
# 196          Ballygunge
# 250             Noapara
# 286         Narendrapur
# 290            New Town
# 291            Jadavpur
# 292           Lake Town
# 293            Jadavpur
# 295               Kasba
# 300         Regent Park
# 315         Madhyamgram
# 352               Kasba
# 392             Barasat
# 393            Jadavpur
# 394      Hindustan More
# 395       Dum Dum Metro
# 396           Ultadanga
# 397         Bhawanipore
# 398           Brahmapur
# 399       Dum Dum Metro
# 400               Kasba
# 401         Chinar Park
# 402             Sealdah
# 404           EM Bypass
# 409            Jadavpur
#
# [30 rows x 28 columns]

# %%
def extract_numeric(price):
    if isinstance(price, str):
        # Remove any non-numeric characters and convert to float
        price = re.sub(r'[^\d.]+', '', price)
        return float(price) if price else np.nan
    return price

# Apply the function to the 'PRICE' column
df_rentals['PRICE'] = df_rentals['PRICE'].apply(extract_numeric)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16244\955704924.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rentals['PRICE'] = df_rentals['PRICE'].apply(extract_numeric)

# %%
df_rentals.head(30)
# Out:
#      PRICE_PER_UNIT_AREA              PROPERTY_TYPE  \
# 11                   7.0      Residential Apartment
# 24                   7.0      Residential Apartment
# 25                   5.0      Residential Apartment
# 38                   5.0  Independent/Builder Floor
# 130                  5.0    Independent House/Villa
# 142                  0.0      Residential Apartment
# 196                  8.0    Independent House/Villa
# 250                  0.0      Residential Apartment
# 286                  0.0      Residential Apartment
# 290                 16.0      Residential Apartment
# 291                 45.0  Independent/Builder Floor
# 292                 10.0      Residential Apartment
# 293                 10.0    Independent House/Villa
# 295                 10.0    Independent House/Villa
# 300                  2.0    Independent House/Villa
# 315                 30.0      Residential Apartment
# 352                 18.0    Independent House/Villa
# 392                  3.0      Residential Apartment
# 393                 14.0    Independent House/Villa
# 394                  6.0    Independent House/Villa
# 395                  2.0    Independent House/Villa
# 396                 16.0    Independent House/Villa
# 397                 13.0  Independent/Builder Floor
# 398                  3.0    Independent House/Villa
# 399                  5.0    Independent House/Villa
# 400                 10.0      Residential Apartment
# 401                 25.0  Independent/Builder Floor
# 402                 18.0    Independent House/Villa
# 404                  2.0      Residential Apartment
# 409                  2.0    Independent House/Villa
#
#                                            DESCRIPTION  OWNTYPE  PRICE_SQFT  \
# 11   A luxurious pg accommodation is available in t...      0.0         7.0
# 24   Property description designed to suit ones lif...      0.0         7.0
# 25   Pg only for working ladies and girl students.\...      0.0         5.0
# 38   Well maintained & secured pg/paying guest in k...      0.0         5.0
# 130  Pg for boy availaible for rent, market is 2 mi...      0.0         5.0
# 142  Book your 2 BHK apartment in New Town, Kolkata...      1.0         0.0
# 196             This area is very homely and peaceful.      0.0         8.0
# 250  Sapnil Residency offers 1 BHK apartments in No...      1.0         0.0
# 286  Prudent Pragati is a residential project, offe...      1.0         0.0
# 290               Awesome view and wonderful amenities      0.0        16.0
# 291  Independent/builder floor is available for pg....      0.0        45.0
# 292  Best location to access every place in kolkata...      0.0        10.0
# 293  Pg for girls in jadavpur- Food and wifi is inc...      0.0        10.0
# 295  Double sharring/ single room pg for girls at k...      0.0        10.0
# 300  Government registered pg for females and highl...      0.0         2.0
# 315  Kolkata north's most popular society signum wi...      0.0        30.0
# 352  My property is in prime location . 1 min walk ...      0.0        18.0
# 392  24 hours security. Elegant surroundings. Vitri...      0.0         3.0
# 393  Pg is located in a very serene area.Rooms are ...      0.0        14.0
# 394  A tidy, clean girls' pg is available near kabi...      0.0         6.0
# 395  Nandi ladies pg, dum dum station, near bandhu ...      0.0         2.0
# 396  This is a gents stay facility\n2 out of 4 room...      0.0        16.0
# 397  A decent semi-Furnished pg/paying guest in bha...      0.0        13.0
# 398  Near to masterda surya sen metro station , ban...      0.0         3.0
# 399  Nandi ladies pg, 4 shearing bed available, dum...      0.0         5.0
# 400  Apartment available for rent in kasba, kolkata...      0.0        10.0
# 401  My property is situated beside the main road a...      0.0        25.0
# 402  At prof.S home pg accommodation for male stude...      0.0        18.0
# 404  Walking distance from geetanjali metro. Bus st...      0.0         2.0
# 409  Dadu's mess\nBoys' pg\n Type (1)-Rent 2500 \n(...      0.0         2.0
#
#      BALCONY_NUM  AGE                                           locality  \
# 11           1.0  3.0  {'CITY': '30', 'CITY_NAME': 'Kolkata Central',...
# 24           3.0  3.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 25           1.0  2.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 38           1.0  2.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 130          0.0  1.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 142          2.0  5.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 196          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 250          2.0  5.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 286          2.0  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 290          1.0  2.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 291          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 292          1.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 293          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 295          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 300          1.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 315          2.0  6.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 352          2.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 392          1.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 393          0.0  1.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 394          1.0  2.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 395          0.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 396          1.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 397          1.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 398          0.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 399          0.0  3.0  {'CITY': '26', 'CITY_NAME': 'Kolkata North', '...
# 400          1.0  2.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 401          1.0  6.0  {'CITY': '28', 'CITY_NAME': 'Kolkata East', 'L...
# 402          2.0  3.0  {'CITY': '30', 'CITY_NAME': 'Kolkata Central',...
# 404          1.0  3.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 409          0.0  1.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
#
#                 CITY  BEDROOM_NUM  ...                 PROP_NAME    PRICE  \
# 11   Kolkata Central          4.0  ...    Ganga Jamuna Apartment  11000.0
# 24      Kolkata East          4.0  ...      Bhariravi apartment   10000.0
# 25     Kolkata North          3.0  ...  Vijay Lakshmi Apartments   6000.0
# 38     Kolkata South          4.0  ...       Sunday On The House  10000.0
# 130    Kolkata South          2.0  ...      Green View Residency   3000.0
# 142     Kolkata East          2.0  ...                 Woodwinds      NaN
# 196    Kolkata South          2.0  ...   Hive Pinnacle Residency   5001.0
# 250    Kolkata North          1.0  ...          Sapnil Residency      NaN
# 286    Kolkata South          1.0  ...           Prudent Pragati      NaN
# 290     Kolkata East          1.0  ...           New Town Tower    4900.0
# 291    Kolkata South          1.0  ...           New Town Tower    8000.0
# 292    Kolkata North          2.0  ...             Bangur Avenue   7501.0
# 293    Kolkata South          2.0  ...             Bangur Avenue   8000.0
# 295    Kolkata South          1.0  ...      Puja Apartment Kasba   6200.0
# 300    Kolkata South          6.0  ...    Shanti Niketan Complex   5000.0
# 315    Kolkata North          4.0  ...          Signum  Windmere  45000.0
# 352    Kolkata South          2.0  ...                  Srijoyee  18000.0
# 392    Kolkata North          2.0  ...          RDB Regent Pearl   3000.0
# 393    Kolkata South          2.0  ...          RDB Regent Pearl   2800.0
# 394    Kolkata South          3.0  ...          RDB Regent Pearl   4500.0
# 395    Kolkata North          4.0  ...          RDB Regent Pearl   2800.0
# 396    Kolkata North          1.0  ...          RDB Regent Pearl   5000.0
# 397    Kolkata South          2.0  ...          RDB Regent Pearl   4000.0
# 398    Kolkata South          2.0  ...          RDB Regent Pearl   2350.0
# 399    Kolkata North          2.0  ...          RDB Regent Pearl   2850.0
# 400    Kolkata South          2.0  ...       jahura bazarsociety   3000.0
# 401     Kolkata East          5.0  ...       jahura bazarsociety   3100.0
# 402  Kolkata Central          3.0  ...       jahura bazarsociety   3600.0
# 404    Kolkata South          2.0  ...                Green View   2500.0
# 409    Kolkata South          3.0  ...               DADU'S MESS   2500.0
#
#     AREA IN SQFT              status    ownership_type FURNISH  LATTITUDE  \
# 11        1500.0           FURNISHED       SHARED BY 3     1.0  22.543910
# 24        1300.0           FURNISHED       SHARED BY 2     1.0  22.581047
# 25        1200.0        PRIVATE ROOM          for rent     4.0  22.650056
# 38        2000.0           FURNISHED       SHARED BY 3     1.0  22.534637
# 130        600.0           FURNISHED       SHARED BY 2     1.0  22.527344
# 142        789.0  UNDER CONSTRUCTION       NEW BOOKING     0.0  22.592205
# 196        600.0           FURNISHED       SHARED BY 2     1.0  22.533000
# 250        657.5  UNDER CONSTRUCTION       NEW BOOKING     0.0  22.641617
# 286        713.0  UNDER CONSTRUCTION        NEW LAUNCH     0.0  22.434568
# 290        300.0           FURNISHED       SHARED BY 2     1.0  22.600691
# 291        160.0         SHARED BY 5          for rent     4.0  22.495000
# 292        750.0         SHARED BY 2          for rent     2.0  22.606173
# 293        800.0           FURNISHED       SHARED BY 2     1.0  22.495000
# 295        600.0           FURNISHED       SHARED BY 2     1.0  22.519587
# 300       2000.0           FURNISHED       SHARED BY 2     1.0  22.487844
# 315       1657.0      FOR SINGLE MEN  FOR SINGLE WOMEN     2.0  22.698023
# 352        950.0      FOR SINGLE MEN  FOR SINGLE WOMEN     4.0  22.513630
# 392        850.0         SHARED BY 2          for rent     4.0  22.696866
# 393        200.0           FURNISHED       SHARED BY 2     1.0  22.502198
# 394        680.0         SHARED BY 3          for rent     4.0  22.457894
# 395       1200.0           FURNISHED       SHARED BY 4     1.0  22.621122
# 396        300.0           FURNISHED      PRIVATE ROOM     1.0  22.595870
# 397        300.0        PRIVATE ROOM          for rent     4.0  22.532300
# 398        600.0         SHARED BY 2          for rent     4.0  22.459650
# 399        500.0           FURNISHED       SHARED BY 4     1.0  22.621056
# 400        300.0         SHARED BY 2          for rent     4.0  22.519587
# 401        120.0           FURNISHED      PRIVATE ROOM     1.0  22.623582
# 402        200.0           FURNISHED       SHARED BY 3     1.0  22.568000
# 404       1051.0         SHARED BY 2          for rent     4.0  22.465030
# 409        900.0         SHARED BY 3          for rent     4.0  22.495000
#
#      LONGITUDE                     Property_Type            Location
# 11   88.355401                       4 BHK Flat   Shakespeare Sarani
# 24   88.462231                       4 BHK Flat        Action Area 1
# 25   88.441311                       3 BHK Flat              Dum Dum
# 38   88.348268  4 BHK Independent Builder Floor      Jadubabur Bazar
# 130  88.344062                  2 Bedroom House            Patuapara
# 142  88.452142                       2 BHK Flat             New Town
# 196  88.359000                  2 Bedroom House           Ballygunge
# 250  88.382771                       1 BHK Flat              Noapara
# 286  88.402079                       1 BHK Flat          Narendrapur
# 290  88.469454                       1 BHK Flat             New Town
# 291  88.372000  1 BHK Independent Builder Floor             Jadavpur
# 292  88.407854                       2 BHK Flat            Lake Town
# 293  88.372000                  2 Bedroom House             Jadavpur
# 295  88.376107                  1 Bedroom House                Kasba
# 300  88.354289                  6 Bedroom House          Regent Park
# 315  88.438331                       4 BHK Flat          Madhyamgram
# 352  88.388275                  2 Bedroom House                Kasba
# 392  88.412716                       2 BHK Flat              Barasat
# 393  88.375414                  2 Bedroom House             Jadavpur
# 394  88.383531                  3 Bedroom House       Hindustan More
# 395  88.394112                  4 Bedroom House        Dum Dum Metro
# 396  88.385700                  1 Bedroom House            Ultadanga
# 397  88.342270  2 BHK Independent Builder Floor          Bhawanipore
# 398  88.365210                  2 Bedroom House            Brahmapur
# 399  88.394049                  2 Bedroom House        Dum Dum Metro
# 400  88.376107                       2 BHK Flat                Kasba
# 401  88.441041  5 BHK Independent Builder Floor          Chinar Park
# 402  88.372000                  3 Bedroom House              Sealdah
# 404  88.394210                       2 BHK Flat            EM Bypass
# 409  88.372000                  3 Bedroom House             Jadavpur
#
# [30 rows x 28 columns]

# %%
df_rentals.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA             0
# PROPERTY_TYPE                   0
# DESCRIPTION                     0
# OWNTYPE                         0
# PRICE_SQFT                      0
# BALCONY_NUM                     0
# AGE                             0
# locality                        0
# CITY                            0
# BEDROOM_NUM                     0
# TOTAL_FLOOR                     0
# SOCIETY_NAME                    0
# PROP_ID                         0
# PREFERENCE                      0
# FORMATTED_LANDMARK_DETAILS      0
# BUILDING_NAME                   0
# TOTAL_LANDMARK_COUNT            0
# FLOOR_NUM                       0
# PROP_NAME                       0
# PRICE                         394
# AREA IN SQFT                    0
# status                          0
# ownership_type                  0
# FURNISH                         0
# LATTITUDE                       0
# LONGITUDE                       0
# Property_Type                   0
# Location                        0
# dtype: int64

# %%
df_rentals.dropna(subset=['PRICE'], inplace=True)
# Out:
# C:\Users\Lenovo\AppData\Local\Temp\ipykernel_16244\3268987692.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_rentals.dropna(subset=['PRICE'], inplace=True)

# %%
df_rentals.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA           0
# PROPERTY_TYPE                 0
# DESCRIPTION                   0
# OWNTYPE                       0
# PRICE_SQFT                    0
# BALCONY_NUM                   0
# AGE                           0
# locality                      0
# CITY                          0
# BEDROOM_NUM                   0
# TOTAL_FLOOR                   0
# SOCIETY_NAME                  0
# PROP_ID                       0
# PREFERENCE                    0
# FORMATTED_LANDMARK_DETAILS    0
# BUILDING_NAME                 0
# TOTAL_LANDMARK_COUNT          0
# FLOOR_NUM                     0
# PROP_NAME                     0
# PRICE                         0
# AREA IN SQFT                  0
# status                        0
# ownership_type                0
# FURNISH                       0
# LATTITUDE                     0
# LONGITUDE                     0
# Property_Type                 0
# Location                      0
# dtype: int64

# %%
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5834 entries, 11 to 38499
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         5834 non-null   float64
#  1   PROPERTY_TYPE               5834 non-null   object
#  2   DESCRIPTION                 5834 non-null   object
#  3   OWNTYPE                     5834 non-null   float64
#  4   PRICE_SQFT                  5834 non-null   float64
#  5   BALCONY_NUM                 5834 non-null   float64
#  6   AGE                         5834 non-null   float64
#  7   locality                    5834 non-null   object
#  8   CITY                        5834 non-null   object
#  9   BEDROOM_NUM                 5834 non-null   float64
#  10  TOTAL_FLOOR                 5834 non-null   float64
#  11  SOCIETY_NAME                5834 non-null   object
#  12  PROP_ID                     5834 non-null   object
#  13  PREFERENCE                  5834 non-null   object
#  14  FORMATTED_LANDMARK_DETAILS  5834 non-null   object
#  15  BUILDING_NAME               5834 non-null   object
#  16  TOTAL_LANDMARK_COUNT        5834 non-null   float64
#  17  FLOOR_NUM                   5834 non-null   object
#  18  PROP_NAME                   5834 non-null   object
#  19  PRICE                       5834 non-null   float64
#  20  AREA IN SQFT                5834 non-null   float64
#  21  status                      5834 non-null   object
#  22  ownership_type              5834 non-null   object
#  23  FURNISH                     5834 non-null   float64
#  24  LATTITUDE                   5834 non-null   float64
#  25  LONGITUDE                   5834 non-null   float64
#  26  Property_Type               5834 non-null   object
#  27  Location                    5834 non-null   object
# dtypes: float64(13), object(15)
# memory usage: 1.3+ MB

# %%
df_rentals.to_csv('rental_real_Estate.csv', index=False)

# %%
df_sales.head()
# Out:
#    PRICE_PER_UNIT_AREA          PROPERTY_TYPE  \
# 0               3662.0  Residential Apartment
# 1              10500.0  Residential Apartment
# 2               8900.0  Residential Apartment
# 3                208.0       Residential Land
# 4               5215.0  Residential Apartment
#
#                                          DESCRIPTION  OWNTYPE  PRICE_SQFT  \
# 0  Book your 2 BHK flat in Srijan Star Swapno Pur...      1.0      3662.0
# 1  Make Natural Quest your next home. This projec...      1.0     10500.0
# 2  Book your 3 BHK apartment in Garia, Kolkata So...      1.0      8900.0
# 3  Dev bhumi in joka, kolkata south by ocean land...      1.0       208.0
# 4  Let your dream of owning a flat come true with...      1.0      5215.0
#
#    BALCONY_NUM  AGE                                           locality  \
# 0          2.0  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 1          2.0  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 2          2.0  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 3          2.0  0.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
# 4          2.0  5.0  {'CITY': '27', 'CITY_NAME': 'Kolkata South', '...
#
#             CITY  BEDROOM_NUM  ...                 PROP_NAME            PRICE  \
# 0  Kolkata South          2.0  ...  Srijan Star Swapno Puron   19.1 L Onwards
# 1  Kolkata South          3.0  ...             Natural Quest  1.17  - 1.18 Cr
# 2  Kolkata South          3.0  ...   Ganguly 4Sight Eminence  1.22  - 1.35 Cr
# 3  Kolkata South          3.0  ...                 Dev Bhumi    1.5  - 5.99 L
# 4  Kolkata South          3.0  ...                 DTC Sojon       60  - 75 L
#
#   AREA IN SQFT              status ownership_type FURNISH  LATTITUDE  \
# 0        570.5  UNDER CONSTRUCTION    NEW BOOKING     0.0  22.364447
# 1       1115.5  UNDER CONSTRUCTION     NEW LAUNCH     0.0  22.518795
# 2       1446.0  UNDER CONSTRUCTION     NEW LAUNCH     0.0  22.513765
# 3       1800.0       READY TO MOVE    NEW BOOKING     0.0  22.453830
# 4       1295.0  UNDER CONSTRUCTION    NEW BOOKING     0.0  22.442130
#
#    LONGITUDE             Property_Type   Location
# 0  88.274642               2 BHK Flat      Amtala
# 1  88.388439               3 BHK Flat   EM Bypass
# 2  88.366680               3 BHK Flat       Garia
# 3  88.249572  Residential land / Plot        Joka
# 4  88.295510               3 BHK Flat        Joka
#
# [5 rows x 28 columns]

# %%
def convert_price(value):
    # Remove commas and extra spaces
    value = value.replace(',', '').strip()
    
    # Remove non-numeric words
    value = re.sub(r'\s+Onwards.*', '', value).strip()
    
    # Handle ranges by splitting
    if '-' in value:
        start, end = value.split('-')
        # Convert each part to numeric
        start = convert_price(start)
        end = convert_price(end)
        # Return the average
        return (start + end) / 2
    
    # Convert 'L' and 'Cr' to numeric values
    if 'L' in value:
        return float(value.replace('L', '').strip()) * 100000
    elif 'Cr' in value:
        return float(value.replace('Cr', '').strip()) * 10000000
    else:
        # Handle cases where the value might already be numeric
        try:
            return float(value)
        except ValueError:
            return None

# Apply the conversion function to the 'PRICE' column
df_sales['PRICE'] = df_sales['PRICE'].apply(convert_price)

# %%
df_sales.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA           0
# PROPERTY_TYPE                 0
# DESCRIPTION                   0
# OWNTYPE                       0
# PRICE_SQFT                    0
# BALCONY_NUM                   0
# AGE                           0
# locality                      0
# CITY                          0
# BEDROOM_NUM                   0
# TOTAL_FLOOR                   0
# SOCIETY_NAME                  0
# PROP_ID                       0
# PREFERENCE                    0
# FORMATTED_LANDMARK_DETAILS    0
# BUILDING_NAME                 0
# TOTAL_LANDMARK_COUNT          0
# FLOOR_NUM                     0
# PROP_NAME                     0
# PRICE                         0
# AREA IN SQFT                  0
# status                        0
# ownership_type                0
# FURNISH                       2
# LATTITUDE                     0
# LONGITUDE                     0
# Property_Type                 0
# Location                      0
# dtype: int64

# %%
df_sales.dropna(subset=['FURNISH'], inplace=True)

# %%
df_sales.isnull().sum()
# Out:
# PRICE_PER_UNIT_AREA           0
# PROPERTY_TYPE                 0
# DESCRIPTION                   0
# OWNTYPE                       0
# PRICE_SQFT                    0
# BALCONY_NUM                   0
# AGE                           0
# locality                      0
# CITY                          0
# BEDROOM_NUM                   0
# TOTAL_FLOOR                   0
# SOCIETY_NAME                  0
# PROP_ID                       0
# PREFERENCE                    0
# FORMATTED_LANDMARK_DETAILS    0
# BUILDING_NAME                 0
# TOTAL_LANDMARK_COUNT          0
# FLOOR_NUM                     0
# PROP_NAME                     0
# PRICE                         0
# AREA IN SQFT                  0
# status                        0
# ownership_type                0
# FURNISH                       0
# LATTITUDE                     0
# LONGITUDE                     0
# Property_Type                 0
# Location                      0
# dtype: int64

# %%
df_sales.to_csv('sales_real_Estate.csv', index=False)

# %%
df_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 32270 entries, 0 to 38498
# Data columns (total 28 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   PRICE_PER_UNIT_AREA         32270 non-null  float64
#  1   PROPERTY_TYPE               32270 non-null  object
#  2   DESCRIPTION                 32270 non-null  object
#  3   OWNTYPE                     32270 non-null  float64
#  4   PRICE_SQFT                  32270 non-null  float64
#  5   BALCONY_NUM                 32270 non-null  float64
#  6   AGE                         32270 non-null  float64
#  7   locality                    32270 non-null  object
#  8   CITY                        32270 non-null  object
#  9   BEDROOM_NUM                 32270 non-null  float64
#  10  TOTAL_FLOOR                 32270 non-null  float64
#  11  SOCIETY_NAME                32270 non-null  object
#  12  PROP_ID                     32270 non-null  object
#  13  PREFERENCE                  32270 non-null  object
#  14  FORMATTED_LANDMARK_DETAILS  32270 non-null  object
#  15  BUILDING_NAME               32270 non-null  object
#  16  TOTAL_LANDMARK_COUNT        32270 non-null  float64
#  17  FLOOR_NUM                   32270 non-null  object
#  18  PROP_NAME                   32270 non-null  object
#  19  PRICE                       32270 non-null  float64
#  20  AREA IN SQFT                32270 non-null  float64
#  21  status                      32270 non-null  object
#  22  ownership_type              32270 non-null  object
#  23  FURNISH                     32270 non-null  float64
#  24  LATTITUDE                   32270 non-null  float64
#  25  LONGITUDE                   32270 non-null  float64
#  26  Property_Type               32270 non-null  object
#  27  Location                    32270 non-null  object
# dtypes: float64(13), object(15)
# memory usage: 7.1+ MB
